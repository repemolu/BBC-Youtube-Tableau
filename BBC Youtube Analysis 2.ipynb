# %%
from googleapiclient.discovery import build
import pandas as pd
import os

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
api_key = 'AIzaSyAyWzAOa60zFZ4EbIjRcmhh9L7KUbFEx2k'
channel_id = 'UC16niRr50-MSBwiO3YDb3RA'

youtube = build('youtube','v3', developerKey = api_key)

# %% [markdown]
# ## Get Channel Stats

# %%
def get_channel_stats(youtube, channel_id):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=channel_id)
    response = request.execute() 
    
    data = dict(Channel_name = response['items'][0]['snippet']['title'],
                    Subscribers = response['items'][0]['statistics']['subscriberCount'],
                    Views = response['items'][0]['statistics']['viewCount'],
                    Total_videos = response['items'][0]['statistics']['videoCount'],
                    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads'])
    
    

    return data

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'Channel_name': 'BBC News',
#  'Subscribers': '14200000',
#  'Views': '4437300493',
#  'Total_videos': '18356',
#  'playlist_id': 'UU16niRr50-MSBwiO3YDb3RA'}

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_comments_info(youtube, channel_id):
    
    request = youtube.commentThreads().list(
                part = 'snippet, replies',
                allThreadsRelatedToChannelId = channel_id)
                
    response= request.execute()
    
    return response

# %%
get_comments_info(youtube, channel_id)
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'SyCvrcVUuoWqLfJakQvZAQ4kslw',
#  'nextPageToken': '',
#  'pageInfo': {'totalResults': 18, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'LpuPjoB3Yfg0Xq2FKwLaPEt1Gf8',
#    'id': 'Ugx2wBve1Spx60BbOuV4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gD7m_GYOgm2mD2A8H5INtExQAHs',
#      'id': 'Ugx2wBve1Spx60BbOuV4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'Slava Ukraine !',
#       'textOriginal': 'Slava Ukraine !',
#       'authorDisplayName': 'Jim Timber',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Pc__AwSHGbNz-wmJI8KfBNWrBb-8YcTToBbJAxdUSH7Fxj147VHvzIxbC_8zObbyz9Qg2VX1tg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCjVu8PG69vnW7ktueuVpSwQ',
#       'authorChannelId': {'value': 'UCjVu8PG69vnW7ktueuVpSwQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:30:24Z',
#       'updatedAt': '2023-05-09T11:30:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qiuopajnueeXUd6-TNnDYlWC6TU',
#    'id': 'UgzgtFSiB9oZh8yhmMB4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'KyRrjCpFvavxwkyCVySvP5qDtzw',
#      'id': 'UgzgtFSiB9oZh8yhmMB4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'Aaahh yes, that very Russian moment, when you celebrate victory day over Nazi-Germany, but with the plot twist of being an orc of Mordor yourself 🤡',
#       'textOriginal': 'Aaahh yes, that very Russian moment, when you celebrate victory day over Nazi-Germany, but with the plot twist of being an orc of Mordor yourself 🤡',
#       'authorDisplayName': 'Gryzor88',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOOselLqFdjrztDcZH5oz4qgS7G8e-KXK2rHA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCeh3LjqXhpAUXQY-waruzFg',
#       'authorChannelId': {'value': 'UCeh3LjqXhpAUXQY-waruzFg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:59Z',
#       'updatedAt': '2023-05-09T11:29:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'E01X6wbB-H3MiApynlrvRvPwVnI',
#    'id': 'UgwYBtzk_3mckg4RM8x4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'd6mQ8Cj_8GU',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mKXgOto77v6Q6AVpqxPGntMYUtw',
#      'id': 'UgwYBtzk_3mckg4RM8x4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'd6mQ8Cj_8GU',
#       'textDisplay': 'recent independent polls has shown close to 60% in support of IK and the PTI and the other 15 political party&#39;s have 40% among themselves.',
#       'textOriginal': "recent independent polls has shown close to 60% in support of IK and the PTI and the other 15 political party's have 40% among themselves.",
#       'authorDisplayName': 'Mohammad ali',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPhiWjOIy7DcEeiZq_aHrdui-fYZYUajpN2vtI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCj4C8KW5r89mLmC2weScoRw',
#       'authorChannelId': {'value': 'UCj4C8KW5r89mLmC2weScoRw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:54Z',
#       'updatedAt': '2023-05-09T11:29:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mPxLL5oatb53NpH1FXsR7g-byVs',
#    'id': 'Ugzffmt1xrgaBKAi9iV4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2sM_aVdqpVT1edhCuEDXinFsmh4',
#      'id': 'Ugzffmt1xrgaBKAi9iV4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'attacking a defencless person who dont want to fight is nothing to be proud of<br><br>Putin is a dog .',
#       'textOriginal': 'attacking a defencless person who dont want to fight is nothing to be proud of\n\nPutin is a dog .',
#       'authorDisplayName': 'Amit Ranaware',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/68Gbq-IVs4l6cSmluWXDfwTdL4E9p9lAJ8yVUMc9-2BK88pTTZ8iWwoi7jGEurHi1J_bWpsMRw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4bCBqyj4bqB6H-9OkKX6ig',
#       'authorChannelId': {'value': 'UC4bCBqyj4bqB6H-9OkKX6ig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:41Z',
#       'updatedAt': '2023-05-09T11:29:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'eYhDjzUSvsND5HkvPyv_65VdcE0',
#    'id': 'UgwWm48UujBw44sRrY94AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': '49UmG08dpbg',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bI3uCphpu-Ik8QZY-ycpfUlGj20',
#      'id': 'UgwWm48UujBw44sRrY94AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': '49UmG08dpbg',
#       'textDisplay': 'Ну что пацаны и пацанессы, кто сегодня нервничал?',
#       'textOriginal': 'Ну что пацаны и пацанессы, кто сегодня нервничал?',
#       'authorDisplayName': 'obnormal',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNAlCTr7S1mv-9Ddq0XR1iBhQ6BT4c6SUV-GLb-1Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmZKUQptalVAwur_12wiX5w',
#       'authorChannelId': {'value': 'UCmZKUQptalVAwur_12wiX5w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:38Z',
#       'updatedAt': '2023-05-09T11:29:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '8eLehIz8a8gwOygD0S5uVum4Jp0',
#    'id': 'UgyJk9XmMyglbbcj_hV4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'd6mQ8Cj_8GU',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '795ubYcwlY9weVVRtAtCNsIqsMs',
#      'id': 'UgyJk9XmMyglbbcj_hV4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'd6mQ8Cj_8GU',
#       'textDisplay': 'Love 😘❤️ Awesome 😘❤️🔥💎🦁🤟',
#       'textOriginal': 'Love 😘❤️ Awesome 😘❤️🔥💎🦁🤟',
#       'authorDisplayName': 'Gayatri Sardana',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNBNb1II8lE25IskyDdL7wYCQSSBrF1omOLCdfFZpU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnf6ID1GPSWLmNPlgS3vUkA',
#       'authorChannelId': {'value': 'UCnf6ID1GPSWLmNPlgS3vUkA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:31Z',
#       'updatedAt': '2023-05-09T11:29:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '6L45xrqngZqBo0Ht1zhQOjOZAww',
#    'id': 'UgwDSJ7AWG5hZus-g3J4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2009bs9uh8aVGg_EQ1pbSZOhlJE',
#      'id': 'UgwDSJ7AWG5hZus-g3J4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'The BBC loves propaganda almost as much as money launderers love Ukraine.',
#       'textOriginal': 'The BBC loves propaganda almost as much as money launderers love Ukraine.',
#       'authorDisplayName': 'Buttsy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOwyxf4bBQnFW_s47H8ZxKZscK5MT_G40L2EgSaSdD4XLAsJiTxnmG8XadRFqF3=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8DBZkWJLo-ahd_tJyVRGcw',
#       'authorChannelId': {'value': 'UC8DBZkWJLo-ahd_tJyVRGcw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:29:16Z',
#       'updatedAt': '2023-05-09T11:29:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'voLdmFQ1O79phGOn_3Y_IcJHurU',
#    'id': 'Ugz-Exz6CSFmFezGhZJ4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mP-4tpaQ69-7XiaA3U6gwTDBuDk',
#      'id': 'Ugz-Exz6CSFmFezGhZJ4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': '9 May 2030: President Putin still calls for &#39;victory&#39;',
#       'textOriginal': "9 May 2030: President Putin still calls for 'victory'",
#       'authorDisplayName': 'appletree',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOezj7MLluWdjFfU1IIJ5povSXTTiRVnJzPbg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCL9MOzNzXo-KdEsae0u-C6A',
#       'authorChannelId': {'value': 'UCL9MOzNzXo-KdEsae0u-C6A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:56Z',
#       'updatedAt': '2023-05-09T11:28:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ksc2IiBwP4_PcLVpdx5meZDst9g',
#    'id': 'Ugwpqman6liH5w0ICut4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'X8uOxWK-kDN5v0MFwgO5MQZIL_Y',
#      'id': 'Ugwpqman6liH5w0ICut4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'Good luck Russia 🪆🪆🪆🪆',
#       'textOriginal': 'Good luck Russia 🪆🪆🪆🪆',
#       'authorDisplayName': 'Tasfia life',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ty0Q3X4ZcGpYF0G_otr9GIg3iuy1gPmEzdwuPEmMjTNiu_DHlkZ5aTYYBD_RbJ06Ok3Xe22SQQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCCMeyBbKOqmZwdTfprnw8eg',
#       'authorChannelId': {'value': 'UCCMeyBbKOqmZwdTfprnw8eg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:43Z',
#       'updatedAt': '2023-05-09T11:28:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Y_yI-lRM-Q4Bc20eLmeQ793Y1Pk',
#    'id': 'UgzRiLyyafyc8xyvget4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tnpYNWPBkGtmqKut0GjvLnZrHhw',
#      'id': 'UgzRiLyyafyc8xyvget4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'This parade reminds all of us why we should NEVER pity not only POOtin but also the whole Russian population who don&#39;t give a damn about reality.',
#       'textOriginal': "This parade reminds all of us why we should NEVER pity not only POOtin but also the whole Russian population who don't give a damn about reality.",
#       'authorDisplayName': 'ilshyf',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPlGViKXgHQVHvCacTS4Al08FqbYtMkYZ4wxg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCTHOfJ4QIr-zvPXobB_DB1Q',
#       'authorChannelId': {'value': 'UCTHOfJ4QIr-zvPXobB_DB1Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:41Z',
#       'updatedAt': '2023-05-09T11:28:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2I03jmSkkhb-m1JZw4Dmmochmzs',
#    'id': 'UgwGqE3IqK2WlhXQzt54AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': '49UmG08dpbg',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ulOMOnScdqGF3y35_pEdizjkoo0',
#      'id': 'UgwGqE3IqK2WlhXQzt54AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': '49UmG08dpbg',
#       'textDisplay': 'Ukraine lies a lot...... This is more than likely propaganda😂',
#       'textOriginal': 'Ukraine lies a lot...... This is more than likely propaganda😂',
#       'authorDisplayName': 'Marcus Legion',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPbheqiYTjJK82HMQMR_6j8q6ESfJP4154JS2hllkYbvpezkGAT6DkkOSP5LsFE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbebeBXfNxPWvtUE7te-oSg',
#       'authorChannelId': {'value': 'UCbebeBXfNxPWvtUE7te-oSg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:41Z',
#       'updatedAt': '2023-05-09T11:28:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mwywxSrXaaFgO6sxxWUdsW2bsV8',
#    'id': 'UgwiDfyW3Z88R1TIdNl4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xDni1pOwv1QcLNHb3AVb9YRTpKc',
#      'id': 'UgwiDfyW3Z88R1TIdNl4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'To all Soviet WW2 veterans, and to all of those who were allied with them, wishing you all a happy 9th May Day Celebration!',
#       'textOriginal': 'To all Soviet WW2 veterans, and to all of those who were allied with them, wishing you all a happy 9th May Day Celebration!',
#       'authorDisplayName': 'Concerned Citizen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNdqoMsSU_CYPS5yVs7s7okhl9jJTzfor7LQg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCTPC-ggQbnQVnA39gZbCfrg',
#       'authorChannelId': {'value': 'UCTPC-ggQbnQVnA39gZbCfrg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:36Z',
#       'updatedAt': '2023-05-09T11:28:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9ep44YUQm8TdFFaplfGxDmJfG9E',
#    'id': 'UgyHJTys-af3XpQTddt4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'TiNwx7DUGy2Il2mT0PfQWB2TLPs',
#      'id': 'UgyHJTys-af3XpQTddt4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'That was the last victory for Russia',
#       'textOriginal': 'That was the last victory for Russia',
#       'authorDisplayName': 'olmsa',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOz0Ou1S-kNUnbx2f0QDzZYCQRKadokAP1hjFMIfFfj2ALqs2gAaoWRzWapoI6e=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLVXeMhFG1Zkn54V7Hz4LLQ',
#       'authorChannelId': {'value': 'UCLVXeMhFG1Zkn54V7Hz4LLQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 4,
#       'publishedAt': '2023-05-09T11:28:31Z',
#       'updatedAt': '2023-05-09T11:28:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LTwscRNlnWn1Uvm83qBl-QAd25I',
#    'id': 'UgwkYlTXNsNr6CpRmkt4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'rrYQ7hMhCiT5c_GAYY7zD-U-fk0',
#      'id': 'UgwkYlTXNsNr6CpRmkt4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': '1 Day time the Victory.<br>Still continye the war invaded.<br>Shame on you putbIn',
#       'textOriginal': '1 Day time the Victory.\nStill continye the war invaded.\nShame on you putbIn',
#       'authorDisplayName': 'keith fernandez',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqPzovFpqPyGkcA4tFcIRu0wUcz5rNY-8bEJZQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJQLahYw64-GPPLB4ILsESA',
#       'authorChannelId': {'value': 'UCJQLahYw64-GPPLB4ILsESA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:17Z',
#       'updatedAt': '2023-05-09T11:28:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'rX9cBiBfz_iLnSrlWn-0QT9hLko',
#    'id': 'UgxUD9v9Ie1hkWrXr554AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'rDfk61_sXApW2PdsnYxJhW6AkfM',
#      'id': 'UgxUD9v9Ie1hkWrXr554AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'I guess he is sealing Russia future',
#       'textOriginal': 'I guess he is sealing Russia future',
#       'authorDisplayName': 'Tiger Tiger',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqMs5Dx9Oi4GRe0TZWrTlS585mvJM9eaSV_C=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UClgxc-2UhdQzWeOSZDZDMvQ',
#       'authorChannelId': {'value': 'UClgxc-2UhdQzWeOSZDZDMvQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2023-05-09T11:28:15Z',
#       'updatedAt': '2023-05-09T11:28:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'R3KQ_7wVLbZmoXIcp1YiJ-Sh8kw',
#    'id': 'UgyCecX3OAB1V4yvYXJ4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RXkK_03joQuhbjktj-9RZjPcuvE',
#      'id': 'UgyCecX3OAB1V4yvYXJ4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'Break up of his country, his &quot;country&quot; broke up 30 years ago',
#       'textOriginal': 'Break up of his country, his "country" broke up 30 years ago',
#       'authorDisplayName': 'Jayden',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqN-1DuS5BKS0a24IZk7ch_5LJHNt82Gy20xoInD=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCl9F2I7TAk4OnM3oaeKi5ig',
#       'authorChannelId': {'value': 'UCl9F2I7TAk4OnM3oaeKi5ig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:13Z',
#       'updatedAt': '2023-05-09T11:28:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'QFvmXKYnbDIALH3XXSD-XGYXkfQ',
#    'id': 'Ugzvo2VLABrwqh-q7X14AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'd6mQ8Cj_8GU',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'rdg9wseBBaqWJuFTkPfnb2QmeEA',
#      'id': 'Ugzvo2VLABrwqh-q7X14AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'd6mQ8Cj_8GU',
#       'textDisplay': 'Pakistan🇵🇰 me Imran Khan k sath intehai zulam wa zyati horahi hai, jo log salon se Pakistan 🇵🇰 ko khaa rahe hain wo azad hain.',
#       'textOriginal': 'Pakistan🇵🇰 me Imran Khan k sath intehai zulam wa zyati horahi hai, jo log salon se Pakistan 🇵🇰 ko khaa rahe hain wo azad hain.',
#       'authorDisplayName': 'Syed Sadam Hussain Shah',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/XJqdGjHW7FPaOTgiu81K4thzsPq4FQ7LhVrlI8Ctv5oJo7jFf_Ayc5fyHlSLTdx6t6IF9yX1=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCiXRYSDur4WzxoUObW6EJHQ',
#       'authorChannelId': {'value': 'UCiXRYSDur4WzxoUObW6EJHQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:06Z',
#       'updatedAt': '2023-05-09T11:28:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5fqmdfFSlRyuIoSxsPNq8DavqW4',
#    'id': 'Ugwl6FCrbg5iXJQxr0h4AaABAg',
#    'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#     'videoId': 'yr4VmVRZa4g',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ljaFmJwVWDP7wtM9Z3HQ14m0eR4',
#      'id': 'Ugwl6FCrbg5iXJQxr0h4AaABAg',
#      'snippet': {'channelId': 'UC16niRr50-MSBwiO3YDb3RA',
#       'videoId': 'yr4VmVRZa4g',
#       'textDisplay': 'And what about the russians who didnt wanna invade ukraine but was forced to and got killed anyways?',
#       'textOriginal': 'And what about the russians who didnt wanna invade ukraine but was forced to and got killed anyways?',
#       'authorDisplayName': 'Daniel Jordan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/NGX9Dz6Eh7NGOLcUMNwOYuBx9j92zyK54FObiSr898q7RNkeuxY0-oeFuKDdHDkol1hGBt0wHA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfBdAud2JVxFoZjlWOMGzsA',
#       'authorChannelId': {'value': 'UCfBdAud2JVxFoZjlWOMGzsA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-05-09T11:28:03Z',
#       'updatedAt': '2023-05-09T11:28:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# ## Function to get video ids

# %%
playlist_id = 'UU16niRr50-MSBwiO3YDb3RA'

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
get_video_ids(youtube,playlist_id)
# Out:
# ['yr4VmVRZa4g',
#  'd6mQ8Cj_8GU',
#  'jlbH2EQLDdI',
#  '49UmG08dpbg',
#  'Lf7P2IumTXk',
#  'zMsYjG1YWcU',
#  'xqM7tyIdIJQ',
#  'ifwVZHLRdtQ',
#  's2hZSPbVnbE',
#  '6Ye5IPEKlA4',
#  'dQyXVDOMJ90',
#  'gim72DK2ebQ',
#  '3Z9e8ajH-OM',
#  '12Q3wD_RiEw',
#  'wgi1a_p75Vw',
#  'BsMWhg7K3Z8',
#  'q0WMxiF0idA',
#  'P_jU5ckE4vU',
#  'GebKnIqCZeA',
#  'aJyJu1z6Kz8',
#  '-bx-5KeQPps',
#  '0-lb4CLAjso',
#  'bGSKXqJPftA',
#  '7d8HMmyCJM4',
#  'lXmFlloyXQk',
#  'LvmekWg433I',
#  'w77ddynOnx8',
#  'k0t9sJxKZas',
#  '_exIPOs9DLM',
#  'etwUHCbn6Hg',
#  'Eb2I5XpYXsM',
#  'O1Wj0gouWG0',
#  'nNyiKRAMOW4',
#  'NQMicLluWfs',
#  'lGsv6AwgtYI',
#  'Y_Jij0rssdw',
#  'W_RZbyuPocw',
#  '7mpif52tFo4',
#  '3YVI2lL3HZc',
#  'rbvQhrodfew',
#  'IC__2_OS7qQ',
#  'wHSjrRX_eY4',
#  'IB_rtHBGaS8',
#  'sCLNDYaNRzA',
#  'BPDOPBzuww4',
#  'gubKvPgRed0',
#  'myxL5foaV74',
#  '4lEERfffVf0',
#  '6YCOZuRBzN4',
#  'Sf3eg89orAs',
#  '_j7qunUJ7Jc',
#  'Kz9EyUdnGrQ',
#  'fRGfzm0dUq0',
#  'COXdDj1i4h8',
#  'Lsh8AqT-6iU',
#  'BSgilLv1T14',
#  'Da_epbCudeY',
#  'l-BsEz3VeEs',
#  'PsTYy-UGTxk',
#  'LeZd5vNH_Gg',
#  '8k6cirQv1xM',
#  'I1vC-kUoP6I',
#  'OLSATYjtuxw',
#  'UYknEGsvv0M',
#  'KXYdFxWQwUM',
#  '4ENMEYdVF38',
#  'IUi8Oo0CzW0',
#  'MPzfQnYa6t8',
#  'ByA2Z0Ky0ww',
#  'M60fSmXe09A',
#  '9wl7svYx2w0',
#  'aRNzKa1WSiQ',
#  'i9AkBfOk9Es',
#  'bndsg0eelDs',
#  '4q-V__I2Q3k',
#  'GG2Pupph254',
#  'Izxsut-T0fU',
#  'Y7lmz0jZFQ4',
#  'U0mBHU6O2Tc',
#  'h4ajrPFZPfg',
#  'Jl8To7OMUr8',
#  't5d3fL11br4',
#  'N0gvsLtYdgc',
#  'fGoKrdMYi6o',
#  'DsBGaHywRhs',
#  'XYFZIFkTz-U',
#  '8OulegiGlLg',
#  '-i694GB2Q5c',
#  'vqtdQG-UaKI',
#  'blB2-APxXYo',
#  '2aqzByAyAIk',
#  'IQ47fQhHyQs',
#  'D77XPfUxaNs',
#  'HtPqsrkKnhI',
#  '8i1RNTIeizk',
#  'kSZ0L9hl2R0',
#  'wqlCzaLfEBg',
#  '4dhQg__VLVs',
#  'J0fP6B7nT-4',
#  'BYczjIqWhI4',
#  'YxxsS05thhY',
#  '89b4zQ-P8rs',
#  '2TGEoGaP6BE',
#  'Pc16H2d6Crw',
#  'o8XrjYrw0cg',
#  'ucnwbzd2xI4',
#  'HyjYUEHeKzo',
#  'dL4702cEN8w',
#  'En8s0mCMwYs',
#  't5H-FhBDylI',
#  '0uNu7J07ecw',
#  'q05JquXgacs',
#  '3ftfs_ak8z8',
#  'y8DIPLtkwMs',
#  'yqacDmtj9Rk',
#  '_B8TSQoHJPk',
#  '9LbM4MufEEo',
#  'JzSJsobbhV4',
#  'nf1B7Dhfwt4',
#  'Bfg0cfvPYUA',
#  'G37BirR7TzM',
#  'qhVxyGgfSCc',
#  '7OBFMCAQrTo',
#  'rHw50wF2Yg0',
#  'Ks4f_URJr1s',
#  'wfOpVjU13HQ',
#  '-uzeimfKonU',
#  'NvKlnjXrZ88',
#  'Lo9xfLSGvWQ',
#  '7l-eOWT6sTI',
#  'QGhqYaNzxHY',
#  'd4EhuWjb1wA',
#  'NpJ3Zxsv7E4',
#  'h6_50n35ALs',
#  'jRZJzn8aLwA',
#  'CgwgYaKk4EA',
#  'V2Vk5Yxx-NI',
#  'g2Jfa7lmL54',
#  'Qx_cO7Gh-zQ',
#  'BkHBrhLfn9U',
#  'OdNcm0KdpBc',
#  'A-1A8XoA3Qo',
#  'sBtr2RpDAas',
#  'IXnComfUdV4',
#  'IohA4aOxtnA',
#  'bWkxV8HYjsQ',
#  'xF16pnNc_z0',
#  'LK5j3pp0Too',
#  'fZUNRymXCkk',
#  'uHaF7US-m9I',
#  'QB9ZI4RCrSI',
#  'qZU5a99UD-0',
#  'kgQ7zOFDSLw',
#  '-sTjp11VHDA',
#  'eZDAkZS0ApA',
#  'CCzz3Y6IqVA',
#  'DQc92HtdeNQ',
#  'NQbTMQZViTM',
#  'OfFcUfSK3Hc',
#  'HHdCSHsvkJc',
#  'D6MeS0fxwUQ',
#  'BZ07ZV3kji4',
#  'uGeRTmDdqUI',
#  'gvO0uwaejbM',
#  'BPQW3gmXMFY',
#  '2VVDaetyMd4',
#  '700XkUmfbhs',
#  'e5RrVdEoqbk',
#  'nTykMcNxcDY',
#  '7WD9kZtSvPg',
#  '8gSsoP6ZR9o',
#  'AfpY1lEw5lM',
#  'cRiSSV5pfzk',
#  'om91gdisuco',
#  'yQWk6OReiWU',
#  'ikhV7Yu-ygs',
#  'J_8sR-y7VFA',
#  'eYK8vl1p2Jo',
#  'mA00lNlD_GA',
#  'euAr_6GFFH0',
#  '961_sjY68e0',
#  'tLH6wd246LA',
#  'u2ahxpTuKTI',
#  'B5_eEkWBHkM',
#  'M0ODIuc8E_o',
#  'sUnufdvp19Y',
#  'QZNhsWNHegY',
#  '9vc0jlE6u8Q',
#  'I1RCPiRRP9M',
#  '86tY8Exmfzs',
#  '18_Wq8Wp1JU',
#  'O7FAHOyvbx4',
#  '7wVmu10z8y0',
#  'FGLo_j778e4',
#  'JtIE9Wahgto',
#  'BCrNt0n-vnw',
#  'nx0BJdSyLu0',
#  'PPg2D80rvZs',
#  'cg0AmlWmdKc',
#  'uosU5nknUCA',
#  'Gt-pcXXOJxw',
#  'SwvaTpMKvDY',
#  'pvxh8Sw4Z4U',
#  '1jhY2fhAsh8',
#  'nqeWhvDfAwA',
#  'HF1D_2luyoE',
#  'VS0FR9pcNNQ',
#  'zX9emwKYemE',
#  'yivEMGF11NA',
#  'uBi80SNJnSg',
#  'zlGXNGPRzuk',
#  'AqAOVna-Ryo',
#  'IfNpibIAlWM',
#  'X2X_qbyVU84',
#  'g2_slyqCiZ8',
#  '3r5WyLqlIFw',
#  'M97CTKSFOGY',
#  'OWLHp0zUQIA',
#  'k__o8H31dh8',
#  'GC-XiD8oOo8',
#  'MHTc77PTLVI',
#  'vx_0rPnNEK8',
#  'TgmH1SCfNjY',
#  'ksV1BkcT2WI',
#  'ZzM0SK6HmDs',
#  'OYKBiAcTID0',
#  'Wiz19ux3YiE',
#  'yj5vnypGiiY',
#  'QojWZC484lo',
#  'btz5PS-2hk0',
#  'SKSsnsAEcn8',
#  'BpHqQEThQnU',
#  'kwORou6l1q8',
#  'xNN6t0-eQLo',
#  'upVCd5iodTI',
#  '3ec7JE-Dk8c',
#  'S53cGjMySXI',
#  'd9DLpSC7mbA',
#  'Q1FFbXcrNEQ',
#  '2PC6WzzwHFc',
#  'OEiNJNkSRoU',
#  '6XUtWbVzfOE',
#  'zUh83B6RhqU',
#  'hLRX5qd4Wlw',
#  'CSEUdQYJwOE',
#  'uW8jYFVlKd4',
#  '_E1vEBdTGCc',
#  'MKl4YxKu7lI',
#  'L9v4aahSu14',
#  'qf_HeTaHf60',
#  'Org1ben_dY0',
#  'nz7U961WlfE',
#  '3KOod95OEh4',
#  'p5SApddSRwU',
#  '8AFxbUACcqo',
#  'lYgeZJ75DE8',
#  '99PlJ_fCrEE',
#  'MjO1z2WJqE0',
#  'o4PCe5xyegc',
#  'tFLWfxG7JQI',
#  'zopfkaaG0yY',
#  'CO24FduiaDo',
#  'djB3YH667HE',
#  '6PYTwPrNZFY',
#  'FGWMhmxsdwo',
#  'UryDKvQ0n8I',
#  'auvqMokRqUk',
#  'b9PACiYJwGQ',
#  '-pwgQwkdjIg',
#  '6iK7dFQk8Gw',
#  '2wvRamxNVYs',
#  'rxpLnqhmuQI',
#  'W5b5YgYmElw',
#  'W8I4OlAfB9g',
#  'ezIVS3CBLvU',
#  'lTbi6GPgato',
#  'zC2comTjqX8',
#  '6NNemD3KZE8',
#  '_EgOAy0XEDs',
#  'SgShp-Ci9wA',
#  '81hN82gOztE',
#  '5k1x9R_aRO4',
#  'Ze4qimHHj5o',
#  'hp6NCw0Yk84',
#  'KWf_9s_LfR8',
#  'tgUdVPjtTHI',
#  'eZ_OT8k8bh4',
#  'eLTvX1X8cgI',
#  'bUxuDgHmkIg',
#  'k-_skXsiSN8',
#  '_9R2d_beRFc',
#  '1jpLN3zUrAE',
#  '7giKhs0sD-Y',
#  'cRkp1g0smQc',
#  'mx4HtsQj1Is',
#  'pHLKA0VssdM',
#  'wD2guzd3Mn8',
#  'HjUqAVUNauI',
#  'cREQvGTHgJA',
#  'AdyGgCbFzIE',
#  'hIdyzf554HM',
#  'AX9PSll5Ilk',
#  'IFbBPxLeG3I',
#  'OCUTYbl3cGc',
#  'ghrABtMr8r8',
#  '4aBxa1ODAwI',
#  'd55XUc_u8Hw',
#  'VdL4HKqG1GM',
#  'wcjjw_u7ogo',
#  'aq3ikakPXmc',
#  'RD_dILBNIX0',
#  '5Jcas9vc2zE',
#  'L_Wl-HQU0RM',
#  'agU5GMCBYr4',
#  'vf1DO45hdnc',
#  'cnxgx7DMhtw',
#  'X-q7V_0OkcI',
#  'NR1Tvxaiu2Y',
#  'ZEVXlhgiQ5c',
#  'VVis4k49UW8',
#  '2rPfKb3aquM',
#  'XLw8P9VKETw',
#  'v0krN_XCyo0',
#  '5JuDNUgekRs',
#  'NPUBAx6VfHI',
#  'Sj7n_kNgnPc',
#  'RxviFA1UjzU',
#  '68myXg-Mu5c',
#  '8hPJSTiNjok',
#  'XQkZdBJ-sOY',
#  'UKdv9JmChs4',
#  'm7PTGLxqKmI',
#  '5l7f0CTreSM',
#  'HMF6sC3lNiE',
#  'ZQOVdT1GCDE',
#  'T5rmJjKsjLg',
#  'esqxYO5vsEI',
#  'ZulH9gisAHE',
#  '1j1MxIHSPys',
#  'KhXTjFUWdY4',
#  'nI6LdUzjq7c',
#  'fDi-2_G_nGU',
#  'REXxouOCksE',
#  '_rm8bKs4zSA',
#  'nrQpWlOKfVY',
#  'lGg64NBWJ-4',
#  'RbzddTb11m4',
#  '8Wk3iBw1-ek',
#  'dJy6LBn_fhQ',
#  'oR7pvoNbXK8',
#  'kKKHNJhtMYY',
#  'WLVZaJihVbw',
#  '_qrbNfCwSCQ',
#  'RwcV4DJUEvM',
#  '-y6p97C6mXw',
#  'RtqDLsNa-c4',
#  'nyYru4CkIJ8',
#  '4WPB5hp8WS4',
#  'B6NN7BT_2Rg',
#  'el4Olem8FVs',
#  '-UtuPtIJuaU',
#  '95ROYh6rEps',
#  'mixjwZHWETk',
#  '3VGOfnU3O88',
#  'c9b5IRaPwaU',
#  'EOxRwl8tFFI',
#  'nt6qwc0rGE8',
#  '8sQV6AdgrbQ',
#  'hfTB5TgJq5w',
#  'lI4NL5WhnBI',
#  'bvE2ptfVOA4',
#  '0IcGEYLHSWw',
#  'FbR3K4L2XnA',
#  '9NUlpUotXAY',
#  'kUSnfEzU-dw',
#  'sVkEXCEPFPY',
#  '0XOH-cCGnv0',
#  '0B1QeJ05g6c',
#  'w_c-6WEtzlI',
#  '_iiOz_7OF2o',
#  'r1v1asv8Wsw',
#  'MvwnDV2tjBs',
#  '5RJqK8c_wI0',
#  'gDIzR6hzEQg',
#  'nV6ARxw1vhc',
#  'ujkOQ0nT7Co',
#  '1MonfApOXTw',
#  'G97OniqFfZ8',
#  'ES_IFrCAV14',
#  'x5sHfnr_jnk',
#  'H51uUUoXOI0',
#  'HjX7S89NhCM',
#  '-T16hNpwmZ4',
#  'Ldj0d5Dr77M',
#  'oomSu_5Fg38',
#  'dm4LVmEBGzM',
#  'ZizYgXqwWcA',
#  '9pBErcSMK7Q',
#  'I5YwQIWOFg0',
#  'AlC-258JDoU',
#  'FYJBUUdUtsw',
#  'GSD-FpvgRVM',
#  'VQLoYCAP7_o',
#  'QsRvI31GoFo',
#  'Jl4ZtaY5CqI',
#  '4fvKIsMywoY',
#  'BD5woaErqYM',
#  'WaEPJsPz8EM',
#  'bxcf1tmsxMc',
#  'IdCtAGRqrlA',
#  'wm2b2DMAX_0',
#  'T9usP15RwkU',
#  'zyZUM0jYJpw',
#  'xmF-UVeW5Iw',
#  'QKKvEtR8Ip0',
#  '0AAEC2yzUyc',
#  '87zldvRR5vk',
#  'vdfPW5gkyC4',
#  'HWTnoRofX5o',
#  'MJhtuBamDZ0',
#  'uMNhd34IIng',
#  'dfbqsxUJcc0',
#  'M7fFMqAhdqs',
#  'eOQvVULCkFY',
#  'UY3VphwnyAk',
#  '0g3obmXpa1Q',
#  'bxJhJ5WB6PY',
#  'Yc-zZ4cyuwo',
#  'tASnkL4Lg2U',
#  'Xp_ZL-kbnx0',
#  'PAMzh4EIBLE',
#  'lrrmbDXh74w',
#  'jfpetfR32Qo',
#  'Ko1B1HCXXAM',
#  'csLWuwlwtVg',
#  'B3vaZM8PQIk',
#  'w6WcEhll6dA',
#  'NHN_NBcU7dw',
#  'So24D7606O8',
#  'pJQPbMraGFE',
#  'no2IaCDXEsU',
#  'RkPNbxmoDSU',
#  'R5xyE5JAUL4',
#  'qeHySXr7ykU',
#  'ZYi1Wmpfte0',
#  'm55b7euO2q8',
#  'IpDG3fgSeXI',
#  'EP4QpVu3-B0',
#  'jSthdIrgZ-c',
#  'hMm5HehQ1PA',
#  'zbwdPisnrx4',
#  'CxmIMclLrPs',
#  'JLlcsi7eQFg',
#  'EAIcBSoIpI4',
#  'GVG0gvlqgVs',
#  'TpN0wAgZ8Bk',
#  'sPF_2BXzOi4',
#  'a2mUZsaifeI',
#  '2BHN0-BtVVw',
#  '1h57ICShVvY',
#  'eiWNGcVEUl0',
#  'UcjUVyEWxhE',
#  'ZavHQmGEg84',
#  '9I5cfVCr_7c',
#  'iuhah9HzJJA',
#  '_6ozTiTxRJY',
#  '80E2gQp4UB0',
#  'oTgpOzMb0r4',
#  '4VTsSFljPmI',
#  'MtSdPXsIMZE',
#  '4IzXrirtCUY',
#  'AS-N5o-y3Co',
#  '4E19Pt29Fgc',
#  '33XeDE3fjqY',
#  'lwXrHuACX-s',
#  'empHiOiwBI0',
#  'kkrf1xs1Zk4',
#  'AnDONaao6tw',
#  'GM-4wDtX0YE',
#  'z-VesW7AlzU',
#  'XVx1JWkPR80',
#  'sYa6W_ArHHA',
#  're_5ykjSpKE',
#  'GI9D24qhwRA',
#  '2PEKvGS6Res',
#  '7TE1BBqeA84',
#  'eVVBnTnim9M',
#  'G4i-FBrVT2Q',
#  'r2BFEJ-ydFg',
#  'CG1bVE_0CD0',
#  'vnXUqnaiU4U',
#  'ZL2QDtUdfTM',
#  'IFkxv5OzcuQ',
#  'IZXV2p73vcE',
#  'c66hr-IHOb8',
#  'IJVX_HsYHoU',
#  'nkTF9LOc_WA',
#  'gKRB3DDRIOw',
#  'hlq0aaq6jRw',
#  'WCBCGNePaRs',
#  'JDa_KXCfHpk',
#  'WUy-LqgiJF4',
#  'bxfY2vO1TJk',
#  'fybHtXcjto8',
#  'DV_Cxunq7m4',
#  'KRkZj20AoiA',
#  'qfalTqsCZiA',
#  'SHHQdK1AtTc',
#  'xG9VLnFmHV0',
#  'hdTYdcFw4kM',
#  'Kt5_SFUPWMM',
#  '0mF_JpPY2Nc',
#  'kCI2yTB6OkU',
#  'xOeu3LeURzU',
#  'H9PsrMyy9ec',
#  'CioQUptRGlo',
#  'g28uXeXz9l8',
#  'PrLbNSxzAgU',
#  'd_ThAkEtHoA',
#  '62DfVOLkGSM',
#  'e262OukLO24',
#  'YNyYRqqNl4U',
#  'adz-ORye6Wc',
#  'q9VP54BddMQ',
#  'nn29VJypqAY',
#  'Id3RzZhbpg0',
#  'q7v2TOLEGoQ',
#  'rAYfBdQhf5U',
#  'WVPdeR585qI',
#  'uiYFMova5Hw',
#  'me9HAzlTnlw',
#  'Ka3ApwLgLsw',
#  'O0D7rZXy6j8',
#  'Bt4RS5jTbuI',
#  'wv9YOpvfy_M',
#  'I_DopHE2FyU',
#  'WHIgr1gt8xw',
#  'yArcjW8-nD4',
#  'QktX4lyUADE',
#  '4X-m1uHH_RA',
#  'e2LjI4vB48w',
#  'aq0W9J5iM_4',
#  'qB27Ocek3d0',
#  'ayGaH4F-80I',
#  '8pVWcO2hWcE',
#  'C8UtPDi0zqc',
#  'B8NHg82wbsk',
#  'q4_uh-71Y8o',
#  '72Odve8DrUk',
#  'CHXIF0H-1i4',
#  'qdzsPwyxtYw',
#  '11QtLdqBkB0',
#  'WzqG0Z_fPOw',
#  '0iXUu1d7EU4',
#  'TSgHzDdA5RU',
#  'Ia6PMh3V6U4',
#  '-tu1szlONxw',
#  'TaiC2yomsB8',
#  '5xnFg7F_gnM',
#  'RmGB0b-sFJk',
#  'P51S57-_3u8',
#  'nei9Qtc2Y4Q',
#  'KUFTDPAyH9o',
#  'tbLk1qsq9a8',
#  'iiefydRUWsg',
#  'qXByH_o3CIE',
#  'GNZ3gdFOQlE',
#  'yiuEll0k2tE',
#  '-gC65bhVVKU',
#  'rpXQHAtqyg0',
#  '1UuxydIBLAg',
#  '4ofz7tIsq5M',
#  'wP6KIJ8ZBcM',
#  'MwNiA2c1MIA',
#  'uVAPqZQ0mgU',
#  '-vSYDJsYj7Y',
#  'eZ1Q68cerUE',
#  'c2COfXWsQog',
#  '14qL_ol_zec',
#  'fpzpOn-UcFg',
#  'J_74Q0C8e6M',
#  'V-TAk2z0jIk',
#  'Ho-n1KCEh9I',
#  'NzIUUPH5G88',
#  'IWdPklHm5QQ',
#  '2siV0LMT8-A',
#  'utcKO1dGPhs',
#  '8-fzhFKZd2Y',
#  '-wir3SVruCo',
#  'rpdXRynRMeI',
#  'zHboEI1vvZ4',
#  '0uBgtVQBAKA',
#  'F2Xz47jk4E0',
#  'OWCOz6ToRys',
#  'CDoQgAE04X4',
#  'Iiby67KQP9w',
#  'ImE_fNTXN34',
#  'OyG70h1JZSQ',
#  '2IFT95hg3cQ',
#  '9w1Ky-9b5VY',
#  'fDQb3NPCKmM',
#  'kK_T0_ZyO8E',
#  'buKBhUSTdIE',
#  'uRdU4wRz0mU',
#  'Kcb2KNdbgUk',
#  '4wkVEbPFtAk',
#  'QCg9_myqtKY',
#  't9p5wEFx3PQ',
#  'L84l84SGMyI',
#  'm82nxRSV0gM',
#  '3VPSZoqJurU',
#  'fzWNVXirKEU',
#  'RJoBEpFt3UU',
#  'cDLcZlqlpao',
#  '9CN2Ed6vMmY',
#  '-AZ2ztjYLHU',
#  'toUTvLR7yOc',
#  'rbIpM6UPlEU',
#  'Z2zPMaVaw6M',
#  '95QcsC1srvI',
#  'siZLGBzJmiA',
#  'zrNamKkQLkM',
#  'NImraJHpUVA',
#  'lvVS1RP2Faw',
#  '2uUMvi2RdrA',
#  'KXXMdOwS5IM',
#  'g3nIXMA1j3E',
#  'm_BfMvAc1us',
#  'cp5zaA8iC0w',
#  'bud8xGdH3uU',
#  'R1u6GwyyRnc',
#  'Wh9JXi6Yzgg',
#  'kAV17ZQ3akE',
#  'QF10R91l51U',
#  'Kr5zcxefRs0',
#  'XcBsnCrd40o',
#  '3DcAqa4ogmM',
#  'TcIIAIcNCL8',
#  'ToB_t4sIiKo',
#  'gMLNmc8i_fc',
#  'Zn3WH4_THyc',
#  'M7bc5wsJfv4',
#  'NZhRoMIeDMU',
#  'kAVqKOEFIO4',
#  'agjhlEkmWuU',
#  'rC2I9isSvOI',
#  'Tctgk029Glo',
#  'fPKvX-9duOQ',
#  'xzNd7EYxp4c',
#  'N8LHHKrBMx8',
#  'NcBivy2SICY',
#  'TnX3UdrycUM',
#  'af_085i4TfQ',
#  '5FCY_ke4z7o',
#  'iUYp2J9ADpk',
#  'PYuB-cCJwkU',
#  'mpaE8HdxwJg',
#  '6SWhL3fxO20',
#  'do5fWZVlcqc',
#  'ragFMl1tOtY',
#  'b2GvuPCNhs0',
#  'RZfjMHzRbgU',
#  'Ajg6lhfY-Uk',
#  '90eEs_YPuZ0',
#  '_gItYn8I6LE',
#  'Wn34XX8GTCc',
#  'Qqak-VgZZGI',
#  '4oBkJhb0eyc',
#  '4buILerverE',
#  '4xyvWJ9jrf0',
#  '0GB-KIlFU2w',
#  'fIFqAo_CHZ8',
#  'kgMI5ZmBIyo',
#  'OwEVB_XelJc',
#  '6KtEvuA21EM',
#  'el3ryQmLBCo',
#  'npow8eiaP0s',
#  'S1gg5-sNRAo',
#  'Ygnsdg1U-Ec',
#  'un1-RUzTOsk',
#  'vLO9gViKUBc',
#  'spx6NmCQjzc',
#  '-I7deWgO7QA',
#  'eVgW93q-FUM',
#  'mjLo5LdjsWQ',
#  'tlTsqms6pro',
#  'qwdobQ4e9VI',
#  'RVE-Rby8CKU',
#  'J7tUQ2AUccY',
#  'BeS0MRN2PPc',
#  'JqAQKYGx66M',
#  'Jz-oMdytwJc',
#  'OFrzl7IbvaA',
#  'TGfJUKMq3vE',
#  'h8oQi7UvsxY',
#  'SYGUAkMNBHY',
#  'J8u3CHadwDw',
#  '8f_2VWkKlvo',
#  'Qe9hYl6q16w',
#  'i2zogB2HmHk',
#  'JstRde6QTwE',
#  'c-cJXILRZLw',
#  'SHiM3nAMMyc',
#  'WQ7XhYgjjO0',
#  'jsPiKtYcVH4',
#  'sSGBZ8LwIpU',
#  'HPq9EjOzmGw',
#  'eGypH8AdGNI',
#  'JZSue7z5Mck',
#  'IKhd4g85sIA',
#  'nZDmC4sq6AU',
#  'OWmBNTGBpqs',
#  '3ALWRc6TPO4',
#  'huWHa3TMh14',
#  'ztxJ-Vd-zNo',
#  '_7cbyVQhSQ0',
#  'gqfU2iri8Yw',
#  'LCeuDGejGLw',
#  '_5T__oLytn8',
#  'RCVbviRdpSs',
#  'Aw96R86OBcg',
#  'IyOMBj6GXDY',
#  'V9ODb6YAeFc',
#  'IEil5ewoWL0',
#  'KgC3EvA2Sk0',
#  'DfTpMueIERw',
#  'VNqZr0zmQ-0',
#  'svxDFBmT9m8',
#  '6gmevcyJ3IU',
#  'pjjt4ihzYPk',
#  'EhUTiKi7a54',
#  '46-Gn9dxFNY',
#  'XRi4xOd70GE',
#  '30TpiDwnMYU',
#  'MLMFTHvHRUU',
#  '4o3-q3IriSE',
#  '_k-rG1UuEHo',
#  '8XxS113lZvM',
#  'XhJQq4zSeaw',
#  'wi3ycEyWg1w',
#  '6dwitqlcRnk',
#  'GFSmddcgiDo',
#  '9aZm7HxS5u4',
#  '9_O-fqXcuxc',
#  'ziIp648zNsM',
#  'SW8pgLhuy98',
#  'BGfMOQaQ7Eg',
#  'dtfG1bo19DI',
#  'izZMB816kEY',
#  '70ZnQZEBVuU',
#  'nthStvgQ02Q',
#  'h77Gu3p2KxE',
#  'W6KCkGD2YSM',
#  'KloM9uVcIOY',
#  'ApODpwyCACc',
#  'cmww2lAsTAA',
#  'Jm0bRQRFD9U',
#  'd8IB-oW3rm4',
#  '0I2Hf7pCQUY',
#  'r3uBy3Jgk-I',
#  'CEM_LRpeifs',
#  'N3AxFTEsFYI',
#  'lw7ZpMPleBg',
#  '_LKQ5o0Kr00',
#  'LysUSEVVEvs',
#  'Tl0MjAz4cMs',
#  'ExLGh8SoNUs',
#  'Qz17z4dxpoE',
#  'Bca_vWc5HeA',
#  'Fh1XL_lDa8o',
#  'bC8byiLwwn8',
#  'GGOmYm2xWJo',
#  'SyAs6TYQVts',
#  'nLol0YLSbpM',
#  'Rpw_ImUu-jo',
#  'HTPSMhmHb8s',
#  '4cj2eOzroHg',
#  'A9ijyOMzlBo',
#  'xkcqRHqu7ko',
#  'WJkAoVccHsY',
#  'JCZ9kNA3nPg',
#  'KeHfqOYJ5jc',
#  '4-HfsLlyJVQ',
#  'W1A0VHafBfg',
#  'xcLv1xQ39pM',
#  'I2mAU_44D74',
#  'aUhkaO1ZPlU',
#  'Lls6XO78MwA',
#  'MI2-GwCglMk',
#  'tmA3k7eyoA8',
#  'rXyAWWCYBuo',
#  'k2Q4qOwtogQ',
#  '62OY-uo3TJg',
#  'AqchOxEE-M4',
#  'TIu72Y4T4ok',
#  'ReCiOJCXaIU',
#  'unuGkEUHAdo',
#  'OQBDEZy6Wvk',
#  'uizo8o0rmu4',
#  '4f0itTUU-fw',
#  'WWmNa89JQIA',
#  'jjZe49b2Mes',
#  'w-7kB1KHLFI',
#  '-eML9FiNMec',
#  'esmaDZetxNk',
#  '8hfOaumtt44',
#  'CsY7IEJuQtI',
#  'E_S5NNhqU4E',
#  '_PYYuOUIIg4',
#  'rRboogQXmH4',
#  '5bybLgziBFc',
#  'uczLc-oT6_c',
#  'oyUWNfjZL0Y',
#  '5gWH5cxNbTw',
#  'hr8XEpsNe9s',
#  'V-4UQyCWjgI',
#  'DETXAW-SGyY',
#  'HTJP0O-7wg0',
#  'a1flXamG8Ts',
#  'cckTV5BxZdc',
#  'ubVf0Jr2wWw',
#  'VToOdpkOS0c',
#  '3Je_frH54PY',
#  '6ow5sH7Ee5Q',
#  'By8sF5XCel8',
#  'pwXjvEEAe3k',
#  'DSBWH8dzyeU',
#  '0xDHW9ZD5jQ',
#  'XeRR084KGdE',
#  'wQiRYY-7GE8',
#  'WwJvlKEDmdA',
#  '5LNHeQ3aejQ',
#  'paeuMCN-DdQ',
#  'RzN7zyI4wYA',
#  'ojVN3cF0i7k',
#  'As6H7HWNiOM',
#  'mh94BHN4fEs',
#  'aZKkoWH3EKM',
#  'YECl3C1vnLA',
#  'l9xnMYLlqIo',
#  '1ogcsdJUfQU',
#  'teiod4G-MZk',
#  'Ehty3eZL9ro',
#  'r2Xxll0y3YI',
#  'wuOhGOHZTFk',
#  '7LrlJp54OtY',
#  'KyPmIOgOP60',
#  'Y97WlnPMEbI',
#  'bEQhYxCybDo',
#  'DERcc7I75vU',
#  '0CAm2bc9OGA',
#  'hYRIZHB3LDI',
#  'iLQLsjacu24',
#  'g4FoJelTvHY',
#  'H5qs7lC5gzs',
#  'wTCfAWBSps0',
#  '9f1GzHwYSZY',
#  'yJvjIdzxNFY',
#  '9qM_YTMQFmo',
#  'iXmLr97rDrw',
#  'x328UuXWPNo',
#  '9MfSmedNbmY',
#  '6rxBG9L1ZG8',
#  'DlNeHl1mr1k',
#  'hNj_fm2hCv0',
#  'QySCtf-fBjk',
#  't88-CHESdh8',
#  'bsqglYYrfy0',
#  'OxDDwiAy8EA',
#  'eL6aEuvBHzg',
#  'LaemqDZZkMg',
#  'ztcxy2OCoXw',
#  '9C4BdzEpFAM',
#  'EUVKPXvz1zc',
#  'v0vviujxR_g',
#  'TqqZQTVP3_Y',
#  'd6VDCKSZceQ',
#  'bZm2RCx-Idk',
#  '8AEeKbckRNo',
#  'N3XRdA9fZPc',
#  'J3cWuA-WPSo',
#  'g6GZ1eA_hEI',
#  'BWCCPy7Rg-s',
#  'kOwBLN4A6M4',
#  'XvGkCIgU69Y',
#  'CfYJw7tNSic',
#  'Zt7Tk9MKmdU',
#  'CWpsNEtZeUM',
#  'hivkH3zRxbY',
#  'CQKWWK_N1dw',
#  'uz1ZGkCQ23w',
#  '23sY_KRloI4',
#  '791UtMT1ZXI',
#  'v66mIaBkHls',
#  '7jQ-TfY-stQ',
#  'yIOHxMHCQ78',
#  'McMwyIkj6T4',
#  '7COopdDCAdA',
#  'lR-Pyv65inU',
#  'pRkTX_IyMlg',
#  '_OeXHHhsv3g',
#  '2FA0ijPm6ko',
#  '0UQ5N4cTBJ4',
#  '6W9iV9IUpcE',
#  'UObz-Z2AlIo',
#  'aYBjyha_5fk',
#  'qq1P3qq4W18',
#  'EqwqQVbNOtk',
#  'Lw3tY00gz2g',
#  'ngt_aV3eYV0',
#  'cBkDKL41jC4',
#  'K4RGAOKp5SY',
#  'nCcgbS8fsg0',
#  'lrajyHKWRWE',
#  'w_61vWZHrw8',
#  'Chg84pNS0pw',
#  'CeRV8z_lsx4',
#  'Ls7rKEN4gik',
#  'n0mJuYIUzFY',
#  'yIdDghCBnU4',
#  'yzKu4sehwvw',
#  'QNoTnfCp3vQ',
#  'QdsTNlNKEMA',
#  'y3ILgwzY0CU',
#  '_Saa8Zx7Pt4',
#  'j_6yX_jug00',
#  'TvJj6oElkps',
#  'Ikg0K2NVWbc',
#  '05HS141u4yA',
#  'tpr7KOJicic',
#  'fvdQ47HuSDo',
#  'YF07i-oUHbg',
#  'KL5dmjKA4ew',
#  'ZKPd_YyNf_0',
#  'yKFO1smwDJY',
#  '3ApUtKIHGwg',
#  'SCAwiMIG9o8',
#  'QpKp1gpjOkc',
#  'HA1_r3dNk_Q',
#  'CO6nRcriH8Q',
#  'Ukqxp4NMos8',
#  'tjAO2zENISc',
#  'BlMoygznzY8',
#  '1JpuNUxw00w',
#  'vWeWsWOZ-w0',
#  'K3oy2wrs_YI',
#  '_K97vrl6urY',
#  'uAYW1W1arGQ',
#  'rHhvfCczI8s',
#  '2nCVbVxQr4s',
#  'msu3PlAxAoM',
#  'N3vgk5996gk',
#  'HAIhdHuP8xc',
#  'ETgrIA0nGec',
#  '6giJejuNhNY',
#  'fsav8UDO0uw',
#  'nJrGEGh0jtE',
#  'M4v1criOgAA',
#  'HYmWp9zdi70',
#  'Kcc77Dwoa-0',
#  '-pKkXDH9MLU',
#  'NBCEemBm1hs',
#  'wJWSRZaYomA',
#  'XXlWqN6KXr0',
#  'FHf-8q5M-jM',
#  'lGmxtB2aNV4',
#  'I3j5R-hKrTs',
#  'YExXx3cH_zw',
#  'xUFo5gguGo4',
#  '1tcyC5ZgJ9Q',
#  'v1xjo49iBiI',
#  'LkE3HkypQts',
#  '1oQLgWUgZHg',
#  'b6Z7ZtHH9Sk',
#  'IZiZzz44UIw',
#  '689P98YgfuA',
#  'vQw2RpMXVhY',
#  'syt9p8Q_MnM',
#  'F_gQ9ipIQkY',
#  'lMUltxyLFgc',
#  'X9Xx0tUlfzI',
#  'NapHH2kgjNU',
#  'vDzwAWf8dvo',
#  'lNaWTb2VaWs',
#  'PmSUj5KoQGo',
#  'iGAY_PpgCDA',
#  'W2-2SdpTAK8',
#  'gkCj9BfW32E',
#  '-564LEr7z6Y',
#  'KNG7NL7eqO0',
#  'nKxfz2nWZEk',
#  'I9zEWNChGbw',
#  'MqzqIVDW3KE',
#  'VJNl4XBynx8',
#  'C0SbFXFXj5c',
#  '5cCSzCI9utM',
#  '2jGEz6l5QPE',
#  'BE-QoPYqelQ',
#  'Npl-6jP6jWw',
#  'kdRcHqzRapk',
#  ...]

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet'].get('title'),
                               Published_date = video['snippet'].get('publishedAt'),
                               Views = video['statistics'].get('viewCount'),
                               Comments = video['statistics'].get('commentCount'),
                               Dislikes = video['statistics'].get('dislikeCount'),
                               Likes = video['statistics'].get('likeCount'))
                               
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
get_video_details(youtube, video_ids)
# Out:
# [{'Title': "Russia’s Victory Day parade: President Putin calls for 'victory' - BBC News",
#   'Published_date': '2023-05-09T11:15:03Z',
#   'Views': '44128',
#   'Comments': '864',
#   'Dislikes': None,
#   'Likes': '1007'},
#  {'Title': 'Pakistan’s former PM Imran Khan arrested outside court in Islamabad– BBC News',
#   'Published_date': '2023-05-09T10:30:58Z',
#   'Views': '22399',
#   'Comments': '454',
#   'Dislikes': None,
#   'Likes': '670'},
#  {'Title': 'Apple co-founder says AI may make scams harder to spot – BBC News',
#   'Published_date': '2023-05-09T09:28:26Z',
#   'Views': '9510',
#   'Comments': '0',
#   'Dislikes': None,
#   'Likes': '332'},
#  {'Title': 'Ukraine says it downed Russian cruise missiles aimed at Kyiv – BBC News',
#   'Published_date': '2023-05-09T07:16:28Z',
#   'Views': '34435',
#   'Comments': '330',
#   'Dislikes': None,
#   'Likes': '560'},
#  {'Title': 'Brownsville: Eight dead as car strikes people in Texas border town – BBC News',
#   'Published_date': '2023-05-08T16:00:12Z',
#   'Views': '28687',
#   'Comments': '204',
#   'Dislikes': None,
#   'Likes': '340'},
#  {'Title': 'More than 400 killed in Democratic Republic of Congo floods – BBC News',
#   'Published_date': '2023-05-08T14:29:40Z',
#   'Views': '23399',
#   'Comments': '116',
#   'Dislikes': None,
#   'Likes': '546'},
#  {'Title': 'St Kitts and Nevis is not totally free under King Charles III, says PM – BBC News',
#   'Published_date': '2023-05-08T11:38:36Z',
#   'Views': '66572',
#   'Comments': '668',
#   'Dislikes': None,
#   'Likes': '954'},
#  {'Title': 'Ukraine’s Kyiv faces fourth missile attack from Russia in eight days – BBC News',
#   'Published_date': '2023-05-08T09:09:24Z',
#   'Views': '207438',
#   'Comments': '1991',
#   'Dislikes': None,
#   'Likes': '2339'},
#  {'Title': "Coronation concert: Prince William 'so proud' of King Charles  - BBC News",
#   'Published_date': '2023-05-07T21:59:47Z',
#   'Views': '151163',
#   'Comments': '624',
#   'Dislikes': None,
#   'Likes': '1700'},
#  {'Title': 'Brownsville: Seven dead in Texas as car strikes people - BBC News',
#   'Published_date': '2023-05-07T19:36:24Z',
#   'Views': '92866',
#   'Comments': '990',
#   'Dislikes': None,
#   'Likes': '955'},
#  {'Title': 'Eurovision 2023 final rehearsals get underway in Liverpool - BBC News',
#   'Published_date': '2023-05-07T17:14:07Z',
#   'Views': '22271',
#   'Comments': '192',
#   'Dislikes': None,
#   'Likes': '228'},
#  {'Title': "King's Coronation: The last lamplighters of London - BBC News",
#   'Published_date': '2023-05-07T14:00:34Z',
#   'Views': '43747',
#   'Comments': '75',
#   'Dislikes': None,
#   'Likes': '1020'},
#  {'Title': 'Prince William and Kate meet crowds ahead of Coronation concert - BBC News',
#   'Published_date': '2023-05-07T13:22:18Z',
#   'Views': '66521',
#   'Comments': '164',
#   'Dislikes': None,
#   'Likes': '720'},
#  {'Title': 'King Charles: Coronation street parties take place across UK - BBC News',
#   'Published_date': '2023-05-07T13:07:14Z',
#   'Views': '52323',
#   'Comments': '375',
#   'Dislikes': None,
#   'Likes': '870'},
#  {'Title': "Who is King Charles's Coronation sword-bearer Penny Mordaunt? #Shorts #Coronation #BBCNews",
#   'Published_date': '2023-05-07T12:00:44Z',
#   'Views': '52754',
#   'Comments': '135',
#   'Dislikes': None,
#   'Likes': '1422'},
#  {'Title': 'Ukraine war: Russia evacuates town near nuclear plant - BBC News',
#   'Published_date': '2023-05-07T11:00:13Z',
#   'Views': '659282',
#   'Comments': '1963',
#   'Dislikes': None,
#   'Likes': '4051'},
#  {'Title': "TikTok tracked UK journalist via her cat's account – BBC News",
#   'Published_date': '2023-05-07T09:00:50Z',
#   'Views': '148627',
#   'Comments': '985',
#   'Dislikes': None,
#   'Likes': '2358'},
#  {'Title': 'Eight killed by gunman in Texas mall shooting - BBC News',
#   'Published_date': '2023-05-07T06:13:55Z',
#   'Views': '122933',
#   'Comments': '2084',
#   'Dislikes': None,
#   'Likes': '1818'},
#  {'Title': "Coronation protesters shout 'not my King' - BBC News",
#   'Published_date': '2023-05-06T19:16:37Z',
#   'Views': '52611',
#   'Comments': '516',
#   'Dislikes': None,
#   'Likes': '1043'},
#  {'Title': 'Coronation crowds give their thoughts on the monarchy and Royal Family #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T14:54:50Z',
#   'Views': '28291',
#   'Comments': '35',
#   'Dislikes': None,
#   'Likes': '440'},
#  {'Title': 'Red Arrows fly over King Charles and Royal Family at Buckingham Palace #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T14:38:45Z',
#   'Views': '30994',
#   'Comments': '89',
#   'Dislikes': None,
#   'Likes': '855'},
#  {'Title': 'Prince William kisses King Charles after oath in Coronation #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T14:31:01Z',
#   'Views': '217398',
#   'Comments': '576',
#   'Dislikes': None,
#   'Likes': '8509'},
#  {'Title': 'Anti-monarchy protests staged as King Charles crowned #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T14:17:02Z',
#   'Views': '23273',
#   'Comments': '174',
#   'Dislikes': None,
#   'Likes': '630'},
#  {'Title': 'King Charles and the Royal Family watch the Red Arrows fly over Buckingham Palace - BBC News',
#   'Published_date': '2023-05-06T14:10:29Z',
#   'Views': '77392',
#   'Comments': '215',
#   'Dislikes': None,
#   'Likes': '720'},
#  {'Title': 'King’s Coronation: Royal Family appear on Buckingham Palace balcony - BBC News',
#   'Published_date': '2023-05-06T14:06:50Z',
#   'Views': '293866',
#   'Comments': '1499',
#   'Dislikes': None,
#   'Likes': '2973'},
#  {'Title': "The seven most eye-catching outfits at King Charles's Coronation #Shorts #Coronation #BBCNews",
#   'Published_date': '2023-05-06T14:05:43Z',
#   'Views': '64501',
#   'Comments': '50',
#   'Dislikes': None,
#   'Likes': '1497'},
#  {'Title': 'Troops perform Royal Salute in Buckingham Palace garden following King Charles Coronation - BBC News',
#   'Published_date': '2023-05-06T13:13:09Z',
#   'Views': '262922',
#   'Comments': '610',
#   'Dislikes': None,
#   'Likes': '3146'},
#  {'Title': 'Prince William kisses King Charles on cheek in Coronation ceremony - BBC News',
#   'Published_date': '2023-05-06T13:01:26Z',
#   'Views': '591805',
#   'Comments': '880',
#   'Dislikes': None,
#   'Likes': '3614'},
#  {'Title': 'HM King Charles III leaves Westminster Abbey following Coronation ceremony - BBC News',
#   'Published_date': '2023-05-06T12:36:53Z',
#   'Views': '101896',
#   'Comments': '327',
#   'Dislikes': None,
#   'Likes': '858'},
#  {'Title': 'Moment Queen Camilla is formally crowned #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T12:23:50Z',
#   'Views': '33471',
#   'Comments': '174',
#   'Dislikes': None,
#   'Likes': '602'},
#  {'Title': 'Moment King Charles III is formally crowned #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-06T12:15:26Z',
#   'Views': '33553',
#   'Comments': '100',
#   'Dislikes': None,
#   'Likes': '1178'},
#  {'Title': 'Coronation ceremony: King Charles III and Queen Camilla enter Westminster Abbey - BBC News',
#   'Published_date': '2023-05-06T12:10:28Z',
#   'Views': '46690',
#   'Comments': '183',
#   'Dislikes': None,
#   'Likes': '391'},
#  {'Title': 'Moment Queen Camilla is crowned at Coronation ceremony in Westminster Abbey - BBC News',
#   'Published_date': '2023-05-06T12:08:39Z',
#   'Views': '172864',
#   'Comments': '825',
#   'Dislikes': None,
#   'Likes': '783'},
#  {'Title': 'Moment HM King Charles III is crowned in Coronation ceremony - BBC News',
#   'Published_date': '2023-05-06T12:07:10Z',
#   'Views': '522101',
#   'Comments': '2745',
#   'Dislikes': None,
#   'Likes': '4085'},
#  {'Title': "Moment Prince Harry arrives at King Charles's Coronation #Shorts #Coronation #BBCNews",
#   'Published_date': '2023-05-06T12:04:16Z',
#   'Views': '44849',
#   'Comments': '98',
#   'Dislikes': None,
#   'Likes': '977'},
#  {'Title': "Prince Harry arrives at King Charles's Coronation in Westminster Abbey - BBC News",
#   'Published_date': '2023-05-06T09:53:09Z',
#   'Views': '2007267',
#   'Comments': '3823',
#   'Dislikes': None,
#   'Likes': '9323'},
#  {'Title': 'King Charles and Queen Camilla travel to Westminster Abbey for Coronation ceremony - BBC News',
#   'Published_date': '2023-05-06T09:47:40Z',
#   'Views': '36247',
#   'Comments': '163',
#   'Dislikes': None,
#   'Likes': '336'},
#  {'Title': "Moment anti-monarchy protester is arrested ahead of King Charles's Coronation - BBC News",
#   'Published_date': '2023-05-06T09:05:36Z',
#   'Views': '68514',
#   'Comments': None,
#   'Dislikes': None,
#   'Likes': '736'},
#  {'Title': 'Who will crown King Charles at Westminster Abbey Coronation? - BBC News',
#   'Published_date': '2023-05-06T08:42:09Z',
#   'Views': '26434',
#   'Comments': '87',
#   'Dislikes': None,
#   'Likes': '205'},
#  {'Title': "What it's like reporting on the King's Coronation for BBC News #Shorts #Coronation #BBCNews",
#   'Published_date': '2023-05-06T08:24:49Z',
#   'Views': '15430',
#   'Comments': '72',
#   'Dislikes': None,
#   'Likes': '376'},
#  {'Title': "Troops arrive in London ahead of King Charles's Coronation #Shorts #BBCNews #Coronation",
#   'Published_date': '2023-05-06T06:41:53Z',
#   'Views': '27203',
#   'Comments': '79',
#   'Dislikes': None,
#   'Likes': '529'},
#  {'Title': 'What time does King Charles’s Coronation start and what is the order of service? - BBC News',
#   'Published_date': '2023-05-06T06:29:08Z',
#   'Views': '35995',
#   'Comments': '110',
#   'Dislikes': None,
#   'Likes': '314'},
#  {'Title': 'Life in Russia 14 months after the Ukraine invasion- BBC News',
#   'Published_date': '2023-05-06T06:02:11Z',
#   'Views': '370037',
#   'Comments': '2033',
#   'Dislikes': None,
#   'Likes': '5496'},
#  {'Title': 'Scottish turntable ferry last surviving in the world – BBC News',
#   'Published_date': '2023-05-05T17:00:29Z',
#   'Views': '54812',
#   'Comments': '138',
#   'Dislikes': None,
#   'Likes': '856'},
#  {'Title': 'Proud Boys: How does the US move on from the storming of the Capitol? - BBC Newsnight',
#   'Published_date': '2023-05-05T16:00:14Z',
#   'Views': '30525',
#   'Comments': '453',
#   'Dislikes': None,
#   'Likes': '393'},
#  {'Title': 'Fighting breaks out between Russian and Ukrainian delegations. #Shorts #BBCNews',
#   'Published_date': '2023-05-05T15:16:16Z',
#   'Views': '45974',
#   'Comments': '267',
#   'Dislikes': None,
#   'Likes': '1420'},
#  {'Title': "Ukraine war: Russia's Wagner Group boss says he will pull troops out of Bakhmut - BBC News",
#   'Published_date': '2023-05-05T15:00:29Z',
#   'Views': '200370',
#   'Comments': '933',
#   'Dislikes': None,
#   'Likes': '1868'},
#  {'Title': 'King Charles, Prince William and Kate greet public before Coronation - BBC News',
#   'Published_date': '2023-05-05T13:28:17Z',
#   'Views': '237769',
#   'Comments': '730',
#   'Dislikes': None,
#   'Likes': '2768'},
#  {'Title': 'Russia alleges Ukrainian sabotage after drone strike on Kremlin - BBC News',
#   'Published_date': '2023-05-05T13:00:04Z',
#   'Views': '31933',
#   'Comments': '192',
#   'Dislikes': None,
#   'Likes': '370'},
#  {'Title': 'Women’s lives at risk from lack of maternal mental health support - BBC Newsnight',
#   'Published_date': '2023-05-05T12:00:29Z',
#   'Views': '14280',
#   'Comments': '159',
#   'Dislikes': None,
#   'Likes': '344'},
#  {'Title': 'Sudan: Millions of dollars worth of food aid looted, The World Food Programme says - BBC News',
#   'Published_date': '2023-05-05T11:00:32Z',
#   'Views': '23052',
#   'Comments': '116',
#   'Dislikes': None,
#   'Likes': '203'},
#  {'Title': 'Serbia shooting: Suspect arrested after second mass shooting - BBC News',
#   'Published_date': '2023-05-05T09:29:31Z',
#   'Views': '64642',
#   'Comments': '526',
#   'Dislikes': None,
#   'Likes': '779'},
#  {'Title': "New Alzheimer's drug slows disease by a third - BBC News",
#   'Published_date': '2023-05-04T21:00:17Z',
#   'Views': '37990',
#   'Comments': '120',
#   'Dislikes': None,
#   'Likes': '752'},
#  {'Title': "Sudan family's journey to UK safety after fleeing Khartoum - BBC News",
#   'Published_date': '2023-05-04T19:00:04Z',
#   'Views': '11880',
#   'Comments': '122',
#   'Dislikes': None,
#   'Likes': '128'},
#  {'Title': 'Ed Sheeran wins Thinking Out Loud copyright case – BBC News',
#   'Published_date': '2023-05-04T18:56:10Z',
#   'Views': '60534',
#   'Comments': '362',
#   'Dislikes': None,
#   'Likes': '1525'},
#  {'Title': "US denies Russia's claims it was involved in Kremlin drone attack - BBC News",
#   'Published_date': '2023-05-04T17:00:09Z',
#   'Views': '268561',
#   'Comments': '913',
#   'Dislikes': None,
#   'Likes': '750'},
#  {'Title': 'Proud Boys: Four members found guilty of seditious conspiracy over Capitol riot - BBC News',
#   'Published_date': '2023-05-04T15:28:03Z',
#   'Views': '53415',
#   'Comments': '733',
#   'Dislikes': None,
#   'Likes': '841'},
#  {'Title': 'Coronation preparations underway in London - BBC News',
#   'Published_date': '2023-05-04T14:50:45Z',
#   'Views': '46344',
#   'Comments': '215',
#   'Dislikes': None,
#   'Likes': '398'},
#  {'Title': 'Is Ukraine behind the alleged Kremlin drone attack? - BBC Newsnight',
#   'Published_date': '2023-05-04T13:30:18Z',
#   'Views': '80450',
#   'Comments': '446',
#   'Dislikes': None,
#   'Likes': '430'},
#  {'Title': "Russia's war on Ukraine is 'against everything we stand for', says Mark Rutte - BBC News",
#   'Published_date': '2023-05-04T12:17:26Z',
#   'Views': '57948',
#   'Comments': '1029',
#   'Dislikes': None,
#   'Likes': '1199'},
#  {'Title': 'Russia blames US for alleged Kremlin drone attack - BBC News',
#   'Published_date': '2023-05-04T10:59:57Z',
#   'Views': '367548',
#   'Comments': '3788',
#   'Dislikes': None,
#   'Likes': '3878'},
#  {'Title': "Ukraine's President Zelensky speaks at The Hague - BBC News",
#   'Published_date': '2023-05-04T10:37:04Z',
#   'Views': '38020',
#   'Comments': '511',
#   'Dislikes': None,
#   'Likes': '645'},
#  {'Title': 'Ukraine war: Russia launches wave of air strikes - BBC News',
#   'Published_date': '2023-05-04T09:32:32Z',
#   'Views': '322812',
#   'Comments': '1688',
#   'Dislikes': None,
#   'Likes': '2903'},
#  {'Title': 'Russian navy ships near Nord Stream pipeline blast site, report says - BBC News',
#   'Published_date': '2023-05-03T21:07:19Z',
#   'Views': '80901',
#   'Comments': '974',
#   'Dislikes': None,
#   'Likes': '1022'},
#  {'Title': 'Russian videos appearing to show Kremlin drone attack – what do we know? - BBC News',
#   'Published_date': '2023-05-03T18:58:05Z',
#   'Views': '428429',
#   'Comments': '1373',
#   'Dislikes': None,
#   'Likes': '1759'},
#  {'Title': 'Are people smugglers working with Iranian security to stay in business? - BBC Newsnight',
#   'Published_date': '2023-05-03T18:00:06Z',
#   'Views': '27684',
#   'Comments': '101',
#   'Dislikes': None,
#   'Likes': '461'},
#  {'Title': 'Russia accuses Ukraine of Putin drone assassination attempt \xa0- BBC News',
#   'Published_date': '2023-05-03T14:38:41Z',
#   'Views': '233442',
#   'Comments': '2030',
#   'Dislikes': None,
#   'Likes': '2525'},
#  {'Title': 'Royal fans turn up a week early for Coronation. #Shorts #KingCharles #BBCNews',
#   'Published_date': '2023-05-03T14:30:06Z',
#   'Views': '19378',
#   'Comments': '105',
#   'Dislikes': None,
#   'Likes': '420'},
#  {'Title': 'Sudan: New ceasefire agreed in conflict - BBC News',
#   'Published_date': '2023-05-03T14:00:10Z',
#   'Views': '15602',
#   'Comments': '34',
#   'Dislikes': None,
#   'Likes': '153'},
#  {'Title': 'Coronation: The audacious attempted theft of the Crown Jewels - BBC News',
#   'Published_date': '2023-05-03T13:00:17Z',
#   'Views': '47916',
#   'Comments': '140',
#   'Dislikes': None,
#   'Likes': '712'},
#  {'Title': 'Russia accuses Ukraine of trying to assassinate President Vladimir Putin - BBC News',
#   'Published_date': '2023-05-03T12:27:15Z',
#   'Views': '635765',
#   'Comments': '7091',
#   'Dislikes': None,
#   'Likes': '5444'},
#  {'Title': 'Uganda passes revised anti-LGBTQ+- bill - BBC News',
#   'Published_date': '2023-05-03T12:00:01Z',
#   'Views': '52008',
#   'Comments': '1261',
#   'Dislikes': None,
#   'Likes': '791'},
#  {'Title': 'Serbia shooting: At least 9 killed in Belgrade school shooting - BBC News',
#   'Published_date': '2023-05-03T10:35:38Z',
#   'Views': '314734',
#   'Comments': '2541',
#   'Dislikes': None,
#   'Likes': '2864'},
#  {'Title': 'Controlled explosion after man arrested outside Buckingham Palace, London police say - BBC News',
#   'Published_date': '2023-05-03T10:13:23Z',
#   'Views': '178523',
#   'Comments': '645',
#   'Dislikes': None,
#   'Likes': '937'},
#  {'Title': "'Hungry' student eats art work at Seoul museum. #Shorts #SouthKorea #BBCNews",
#   'Published_date': '2023-05-03T09:23:53Z',
#   'Views': '19084',
#   'Comments': '50',
#   'Dislikes': None,
#   'Likes': '492'},
#  {'Title': 'Children in Afghanistan dying from preventable diseases, says charity - BBC News',
#   'Published_date': '2023-05-03T08:41:04Z',
#   'Views': '13101',
#   'Comments': '241',
#   'Dislikes': None,
#   'Likes': '477'},
#  {'Title': 'The antivax filmmaker who sparked harassment of bereaved families - BBC Newsnight',
#   'Published_date': '2023-05-03T07:00:05Z',
#   'Views': '17326',
#   'Comments': '722',
#   'Dislikes': None,
#   'Likes': '256'},
#  {'Title': 'US TV shows to go off-air as Hollywood writers strike - BBC News',
#   'Published_date': '2023-05-02T19:00:15Z',
#   'Views': '58924',
#   'Comments': '283',
#   'Dislikes': None,
#   'Likes': '841'},
#  {'Title': 'Wrexham: Ryan Reynolds and Rob McElhenney join open-top bus parade - BBC News',
#   'Published_date': '2023-05-02T18:51:21Z',
#   'Views': '372059',
#   'Comments': '534',
#   'Dislikes': None,
#   'Likes': '2257'},
#  {'Title': 'Father says son was sacrificed for BP’s profits as he challenges CEO - BBC News',
#   'Published_date': '2023-05-02T18:00:29Z',
#   'Views': '17863',
#   'Comments': '99',
#   'Dislikes': None,
#   'Likes': '296'},
#  {'Title': 'Coronation: Princess Anne rejects calls for a ‘slimmed down’ monarchy - BBC News',
#   'Published_date': '2023-05-02T17:06:01Z',
#   'Views': '75855',
#   'Comments': '556',
#   'Dislikes': None,
#   'Likes': '1027'},
#  {'Title': 'UN fears mass exodus of refugees from Sudan amid deadly conflict - BBC News',
#   'Published_date': '2023-05-02T15:00:39Z',
#   'Views': '45099',
#   'Comments': '186',
#   'Dislikes': None,
#   'Likes': '421'},
#  {'Title': 'Met Gala 2023: Stars celebrate fashion designer Karl Lagerfeld - BBC News',
#   'Published_date': '2023-05-02T13:00:16Z',
#   'Views': '22091',
#   'Comments': '91',
#   'Dislikes': None,
#   'Likes': '211'},
#  {'Title': 'Inside King Charles III’s golden coronation carriage. #Shorts #Coronation #BBCNews',
#   'Published_date': '2023-05-02T12:31:25Z',
#   'Views': '34269',
#   'Comments': '113',
#   'Dislikes': None,
#   'Likes': '721'},
#  {'Title': "AI 'godfather' quits Google over dangers of Artificial Intelligence - BBC News",
#   'Published_date': '2023-05-02T12:00:13Z',
#   'Views': '454513',
#   'Comments': '2170',
#   'Dislikes': None,
#   'Likes': '7259'},
#  {'Title': 'US could face economic turmoil if another bank faces collapse, money bosses warn - BBC News',
#   'Published_date': '2023-05-02T09:03:24Z',
#   'Views': '749764',
#   'Comments': '2298',
#   'Dislikes': None,
#   'Likes': '4991'},
#  {'Title': 'France pension reforms: May Day rallies turn violent - BBC News',
#   'Published_date': '2023-05-01T16:29:26Z',
#   'Views': '330596',
#   'Comments': '2098',
#   'Dislikes': None,
#   'Likes': '3298'},
#  {'Title': 'Can X-planes solve the sonic boom problem? - BBC News',
#   'Published_date': '2023-05-01T12:00:00Z',
#   'Views': '86950',
#   'Comments': '376',
#   'Dislikes': None,
#   'Likes': '1423'},
#  {'Title': 'Russia launches second pre-dawn missile attack on Ukraine in three days - BBC News',
#   'Published_date': '2023-05-01T10:59:11Z',
#   'Views': '83812',
#   'Comments': '1447',
#   'Dislikes': None,
#   'Likes': '936'},
#  {'Title': 'Sudan hit with air strikes despite truce - BBC News',
#   'Published_date': '2023-05-01T09:18:38Z',
#   'Views': '108769',
#   'Comments': '248',
#   'Dislikes': None,
#   'Likes': '1041'},
#  {'Title': 'Sudan: First consignment of medical aid reaches country – BBC News',
#   'Published_date': '2023-04-30T17:00:01Z',
#   'Views': '50864',
#   'Comments': '109',
#   'Dislikes': None,
#   'Likes': '428'},
#  {'Title': 'Pope Francis urges Hungary not to close door on migrants – BBC News',
#   'Published_date': '2023-04-30T15:39:58Z',
#   'Views': '28249',
#   'Comments': '416',
#   'Dislikes': None,
#   'Likes': '289'},
#  {'Title': 'The US tech millionaire trying to reverse his age - BBC News',
#   'Published_date': '2023-04-30T12:00:07Z',
#   'Views': '147075',
#   'Comments': '911',
#   'Dislikes': None,
#   'Likes': '2145'},
#  {'Title': 'King Charles: Public invited to swear allegiance to king during Coronation – BBC News',
#   'Published_date': '2023-04-30T11:57:04Z',
#   'Views': '462033',
#   'Comments': '5156',
#   'Dislikes': None,
#   'Likes': '1954'},
#  {'Title': 'Sudan’s capital Khartoum faces air strikes and fighting as truce collapses – BBC News',
#   'Published_date': '2023-04-30T09:45:50Z',
#   'Views': '116913',
#   'Comments': '249',
#   'Dislikes': None,
#   'Likes': '1127'},
#  {'Title': 'Sudan: Millions trapped or fleeing as ceasefire unravels – BBC News',
#   'Published_date': '2023-04-29T13:00:27Z',
#   'Views': '98486',
#   'Comments': '366',
#   'Dislikes': None,
#   'Likes': '819'},
#  {'Title': 'Canada’s 450-mile dog race through its frozen north - BBC News',
#   'Published_date': '2023-04-29T12:00:50Z',
#   'Views': '40152',
#   'Comments': '163',
#   'Dislikes': None,
#   'Likes': '833'},
#  {'Title': "How a Boris Johnson row led to the BBC chairman's resignation - BBC News",
#   'Published_date': '2023-04-29T11:00:03Z',
#   'Views': '131721',
#   'Comments': '265',
#   'Dislikes': None,
#   'Likes': '601'},
#  {'Title': 'Ukraine war:\xa0Crimea oil tank set ablaze by reported drone strike – BBC News',
#   'Published_date': '2023-04-29T09:46:47Z',
#   'Views': '487351',
#   'Comments': '1780',
#   'Dislikes': None,
#   'Likes': '5272'},
#  {'Title': 'Pope Francis arrives in Hungary for three-day visit - BBC News',
#   'Published_date': '2023-04-28T18:30:13Z',
#   'Views': '29595',
#   'Comments': '242',
#   'Dislikes': None,
#   'Likes': '376'},
#  {'Title': 'What’s happening in Sudan and why? - BBC News',
#   'Published_date': '2023-04-28T17:17:20Z',
#   'Views': '648965',
#   'Comments': '1163',
#   'Dislikes': None,
#   'Likes': '7619'},
#  {'Title': 'Sudan evacuation plane fired on as it lands at airbase - BBC News',
#   'Published_date': '2023-04-28T16:16:00Z',
#   'Views': '603060',
#   'Comments': '545',
#   'Dislikes': None,
#   'Likes': '3955'},
#  {'Title': "World's first disabled astronaut takes part in flying exercise - BBC News",
#   'Published_date': '2023-04-28T12:59:06Z',
#   'Views': '18660',
#   'Comments': '86',
#   'Dislikes': None,
#   'Likes': '278'},
#  {'Title': 'Sudan ceasefire extended but fighting continues - BBC News',
#   'Published_date': '2023-04-28T12:00:30Z',
#   'Views': '26797',
#   'Comments': '65',
#   'Dislikes': None,
#   'Likes': '438'},
#  {'Title': 'Ukraine hit by Russian missile strikes with multiple people dead  - BBC News',
#   'Published_date': '2023-04-28T09:58:48Z',
#   'Views': '177619',
#   'Comments': '2436',
#   'Dislikes': None,
#   'Likes': '2382'},
#  {'Title': 'BBC chairman Richard Sharp resigns after Boris Johnson loan row - BBC News',
#   'Published_date': '2023-04-28T09:20:33Z',
#   'Views': '45899',
#   'Comments': '295',
#   'Dislikes': None,
#   'Likes': '602'},
#  {'Title': 'Tucker Carlson breaks silence after Fox News exit - BBC News',
#   'Published_date': '2023-04-27T16:00:16Z',
#   'Views': '112494',
#   'Comments': '870',
#   'Dislikes': None,
#   'Likes': '1158'},
#  {'Title': 'TV host Jerry Springer dies aged 79 - BBC News',
#   'Published_date': '2023-04-27T15:07:17Z',
#   'Views': '104906',
#   'Comments': '571',
#   'Dislikes': None,
#   'Likes': '782'},
#  {'Title': 'The Austrian salt mine where Nazis hid stolen art - BBC News',
#   'Published_date': '2023-04-27T14:30:03Z',
#   'Views': '28396',
#   'Comments': '88',
#   'Dislikes': None,
#   'Likes': '355'},
#  {'Title': 'Turkey President Erdogan cancels election campaign appearances - BBC News',
#   'Published_date': '2023-04-27T13:30:26Z',
#   'Views': '82708',
#   'Comments': '391',
#   'Dislikes': None,
#   'Likes': '961'},
#  {'Title': 'Spain braces for hottest ever April temperatures - BBC News',
#   'Published_date': '2023-04-27T12:00:01Z',
#   'Views': '29282',
#   'Comments': '243',
#   'Dislikes': None,
#   'Likes': '267'},
#  {'Title': 'US and South Korea agree key nuclear weapons deal - BBC News',
#   'Published_date': '2023-04-27T10:30:13Z',
#   'Views': '140917',
#   'Comments': '1105',
#   'Dislikes': None,
#   'Likes': '2145'},
#  {'Title': 'US and Philippines conclude their largest ever military exercises  - BBC News',
#   'Published_date': '2023-04-27T09:00:04Z',
#   'Views': '191187',
#   'Comments': '983',
#   'Dislikes': None,
#   'Likes': '3330'},
#  {'Title': 'Sudan: Calls to abide by ceasefire as evacuations continue - BBC News',
#   'Published_date': '2023-04-27T07:45:04Z',
#   'Views': '51888',
#   'Comments': '143',
#   'Dislikes': None,
#   'Likes': '663'},
#  {'Title': "Ukraine's Zelensky holds first war phone call with China's Xi - BBC News",
#   'Published_date': '2023-04-26T17:00:26Z',
#   'Views': '176365',
#   'Comments': '1677',
#   'Dislikes': None,
#   'Likes': '2150'},
#  {'Title': 'Kenya ‘starvation cult’ death toll continues to rise - BBC News',
#   'Published_date': '2023-04-26T15:45:04Z',
#   'Views': '121979',
#   'Comments': '563',
#   'Dislikes': None,
#   'Likes': '1058'},
#  {'Title': 'TikToker trapped in gambling addiction that nearly destroyed his life - BBC Newsnight',
#   'Published_date': '2023-04-26T14:15:00Z',
#   'Views': '21040',
#   'Comments': '153',
#   'Dislikes': None,
#   'Likes': '263'},
#  {'Title': 'Russian opposition leader Alexei Navalny facing terrorism charges - BBC News',
#   'Published_date': '2023-04-26T12:15:00Z',
#   'Views': '31209',
#   'Comments': '373',
#   'Dislikes': None,
#   'Likes': '486'},
#  {'Title': "Ukraine rapidly expanding its 'Army of Drones' - BBC News",
#   'Published_date': '2023-04-26T10:30:12Z',
#   'Views': '259257',
#   'Comments': '859',
#   'Dislikes': None,
#   'Likes': '3433'},
#  {'Title': 'Taliban kill IS leader behind Kabul airport bombing - BBC News',
#   'Published_date': '2023-04-26T09:00:05Z',
#   'Views': '63465',
#   'Comments': '227',
#   'Dislikes': None,
#   'Likes': '688'},
#  {'Title': 'Sudan: Thousands of foreign nationals still trying to flee country – BBC News',
#   'Published_date': '2023-04-26T07:34:32Z',
#   'Views': '61939',
#   'Comments': '182',
#   'Dislikes': None,
#   'Likes': '755'},
#  {'Title': 'Tangaraju Suppiah: Singapore executes man for supplying cannabis – BBC News',
#   'Published_date': '2023-04-26T06:28:29Z',
#   'Views': '58163',
#   'Comments': '1303',
#   'Dislikes': None,
#   'Likes': '496'},
#  {'Title': 'US pours trillions of dollars of public funds into new green industries - BBC News',
#   'Published_date': '2023-04-25T21:49:05Z',
#   'Views': '161000',
#   'Comments': '957',
#   'Dislikes': None,
#   'Likes': '2782'},
#  {'Title': 'Malaria spike in Pakistan and Mozambique due to climate change, report says - BBC News',
#   'Published_date': '2023-04-25T17:00:23Z',
#   'Views': '28294',
#   'Comments': '177',
#   'Dislikes': None,
#   'Likes': '559'},
#  {'Title': 'Fears for Sudan animal sanctuary  - BBC News',
#   'Published_date': '2023-04-25T16:08:20Z',
#   'Views': '10203',
#   'Comments': '91',
#   'Dislikes': None,
#   'Likes': '171'},
#  {'Title': 'How does Joe Biden’s age compare with other world leaders? - BBC News',
#   'Published_date': '2023-04-25T13:30:31Z',
#   'Views': '42748',
#   'Comments': '456',
#   'Dislikes': None,
#   'Likes': '586'},
#  {'Title': '360° Video: Explore inside Westminster Abbey ahead of King Charles’s coronation - BBC News',
#   'Published_date': '2023-04-25T12:35:32Z',
#   'Views': '91272',
#   'Comments': '180',
#   'Dislikes': None,
#   'Likes': '1097'},
#  {'Title': 'Older Americans weigh in on Joe Biden’s age - BBC News',
#   'Published_date': '2023-04-25T11:32:40Z',
#   'Views': '29923',
#   'Comments': '269',
#   'Dislikes': None,
#   'Likes': '388'},
#  {'Title': 'US President Joe Biden confirms 2024 presidential bid – BBC News',
#   'Published_date': '2023-04-25T10:26:45Z',
#   'Views': '42573',
#   'Comments': '691',
#   'Dislikes': None,
#   'Likes': '978'},
#  {'Title': 'Matthew Perry to remove Keanu Reeves from memoir - BBC News',
#   'Published_date': '2023-04-25T08:45:00Z',
#   'Views': '52899',
#   'Comments': '215',
#   'Dislikes': None,
#   'Likes': '332'},
#  {'Title': 'Warring sides agree to ceasefire in Sudan – BBC News',
#   'Published_date': '2023-04-25T07:44:42Z',
#   'Views': '113816',
#   'Comments': '299',
#   'Dislikes': None,
#   'Likes': '661'},
#  {'Title': 'Sudan conflict could engulf region, UN warns - BBC News',
#   'Published_date': '2023-04-24T21:50:06Z',
#   'Views': '328378',
#   'Comments': '831',
#   'Dislikes': None,
#   'Likes': '1962'},
#  {'Title': 'Bangladesh marks 10th anniversary of Rana Plaza disaster - BBC News',
#   'Published_date': '2023-04-24T18:00:13Z',
#   'Views': '16278',
#   'Comments': '53',
#   'Dislikes': None,
#   'Likes': '182'},
#  {'Title': 'Tucker Carlson leaves Fox News - BBC News',
#   'Published_date': '2023-04-24T16:47:42Z',
#   'Views': '193293',
#   'Comments': '2859',
#   'Dislikes': None,
#   'Likes': '2857'},
#  {'Title': 'Credit Suisse reveals results of last financial quarter before rescue - BBC News',
#   'Published_date': '2023-04-24T16:00:37Z',
#   'Views': '23432',
#   'Comments': '25',
#   'Dislikes': None,
#   'Likes': '224'},
#  {'Title': 'Len Goodman: Strictly Come Dancing and Dancing with the Stars judge dies aged 78 - BBC News',
#   'Published_date': '2023-04-24T15:00:12Z',
#   'Views': '35443',
#   'Comments': '70',
#   'Dislikes': None,
#   'Likes': '360'},
#  {'Title': 'How popular is the Royal Family in the UK? - BBC News',
#   'Published_date': '2023-04-24T14:03:20Z',
#   'Views': '88621',
#   'Comments': '1211',
#   'Dislikes': None,
#   'Likes': '1300'},
#  {'Title': 'US President Joe Biden to announce bid for re-election - BBC News',
#   'Published_date': '2023-04-24T11:45:02Z',
#   'Views': '27768',
#   'Comments': '537',
#   'Dislikes': None,
#   'Likes': '373'},
#  {'Title': 'Global military spending surged to all-time high in 2022 - BBC News',
#   'Published_date': '2023-04-24T10:42:47Z',
#   'Views': '43090',
#   'Comments': '351',
#   'Dislikes': None,
#   'Likes': '820'},
#  {'Title': 'Migrants march through Mexico demanding justice over detention centre deaths - BBC News',
#   'Published_date': '2023-04-24T09:00:05Z',
#   'Views': '13164',
#   'Comments': '179',
#   'Dislikes': None,
#   'Likes': '168'},
#  {'Title': 'Sudan humanitarian crisis as diplomats flee - BBC News',
#   'Published_date': '2023-04-24T07:52:39Z',
#   'Views': '122122',
#   'Comments': '314',
#   'Dislikes': None,
#   'Likes': '653'},
#  {'Title': 'What could ‘voice cloning’ technology mean for society? - BBC News',
#   'Published_date': '2023-04-23T17:00:07Z',
#   'Views': '49513',
#   'Comments': '192',
#   'Dislikes': None,
#   'Likes': '947'},
#  {'Title': 'Out of the Shadows: Born from Rape | BBC News',
#   'Published_date': '2023-04-23T12:00:39Z',
#   'Views': '159651',
#   'Comments': '712',
#   'Dislikes': None,
#   'Likes': '3126'},
#  {'Title': 'Sudan evacuation of foreign nationals continues as fighting rages - BBC News',
#   'Published_date': '2023-04-23T10:03:31Z',
#   'Views': '167650',
#   'Comments': '365',
#   'Dislikes': None,
#   'Likes': '1571'},
#  {'Title': 'Sudan army says foreign nationals to be evacuated as Khartoum fighting continues - BBC News',
#   'Published_date': '2023-04-22T14:55:23Z',
#   'Views': '176684',
#   'Comments': '402',
#   'Dislikes': None,
#   'Likes': '1245'},
#  {'Title': 'Inside the world of mobile phone sound design - BBC News',
#   'Published_date': '2023-04-22T12:00:33Z',
#   'Views': '35154',
#   'Comments': '82',
#   'Dislikes': None,
#   'Likes': '880'},
#  {'Title': 'Mifepristone: US Supreme Court preserves abortion drug access - BBC News',
#   'Published_date': '2023-04-22T10:08:50Z',
#   'Views': '23095',
#   'Comments': '294',
#   'Dislikes': None,
#   'Likes': '303'},
#  {'Title': 'AI: What is the future of artificial intelligence? - BBC News',
#   'Published_date': '2023-04-21T21:45:19Z',
#   'Views': '125003',
#   'Comments': '692',
#   'Dislikes': None,
#   'Likes': '2139'},
#  {'Title': "Syrian earthquake survivors feel 'forgotten' - BBC News",
#   'Published_date': '2023-04-21T16:51:56Z',
#   'Views': '32894',
#   'Comments': '177',
#   'Dislikes': None,
#   'Likes': '708'},
#  {'Title': 'Ukraine war: Moment Russian fighter jet accidentally bombs own city - BBC News',
#   'Published_date': '2023-04-21T15:00:41Z',
#   'Views': '154508',
#   'Comments': '675',
#   'Dislikes': None,
#   'Likes': '1313'},
#  {'Title': 'Is American women’s access to abortion drug Mifepristone about to stop? - BBC Newsnight',
#   'Published_date': '2023-04-21T14:00:25Z',
#   'Views': '16870',
#   'Comments': '213',
#   'Dislikes': None,
#   'Likes': '171'},
#  {'Title': 'Failed Sudan ceasefire leads to muted Eid celebrations - BBC News',
#   'Published_date': '2023-04-21T12:30:22Z',
#   'Views': '55065',
#   'Comments': '194',
#   'Dislikes': None,
#   'Likes': '705'},
#  {'Title': 'Mini responds to Chinese ice cream racism uproar - BBC News',
#   'Published_date': '2023-04-21T11:00:36Z',
#   'Views': '121820',
#   'Comments': '1330',
#   'Dislikes': None,
#   'Likes': '853'},
#  {'Title': 'UK Deputy Prime Minister Dominic Raab resigns over bullying report - BBC News',
#   'Published_date': '2023-04-21T09:50:45Z',
#   'Views': '129701',
#   'Comments': '569',
#   'Dislikes': None,
#   'Likes': '958'},
#  {'Title': 'Inside a submarine smuggling cocaine to Europe – BBC News',
#   'Published_date': '2023-04-21T08:13:53Z',
#   'Views': '176605',
#   'Comments': '461',
#   'Dislikes': None,
#   'Likes': '1162'},
#  {'Title': "SpaceX: Why did Elon Musk's Starship rocket explode? - BBC News",
#   'Published_date': '2023-04-20T22:00:05Z',
#   'Views': '217040',
#   'Comments': '1224',
#   'Dislikes': None,
#   'Likes': '2473'},
#  {'Title': 'Alec Baldwin Rust charges dropped, say lawyers - BBC News',
#   'Published_date': '2023-04-20T21:05:50Z',
#   'Views': '28650',
#   'Comments': '386',
#   'Dislikes': None,
#   'Likes': '566'},
#  {'Title': "Hong Kong's last standing protesters testing Beijing’s security law - BBC Newsnight",
#   'Published_date': '2023-04-20T18:00:09Z',
#   'Views': '38205',
#   'Comments': '391',
#   'Dislikes': None,
#   'Likes': '814'},
#  {'Title': "Mums of daughters murdered by ex-partners want 'immoral' sentencing changed - BBC Newsnight",
#   'Published_date': '2023-04-20T17:00:11Z',
#   'Views': '15429',
#   'Comments': '111',
#   'Dislikes': None,
#   'Likes': '277'},
#  {'Title': 'Will new UK voter ID rules make it harder to vote? - BBC News',
#   'Published_date': '2023-04-20T16:00:11Z',
#   'Views': '37782',
#   'Comments': '582',
#   'Dislikes': None,
#   'Likes': '539'},
#  {'Title': 'Elon Musk’s SpaceX Starship rocket explodes minutes after launch #Shorts #Starship #ElonMusk',
#   'Published_date': '2023-04-20T15:11:09Z',
#   'Views': '85292',
#   'Comments': '191',
#   'Dislikes': None,
#   'Likes': '2006'},
#  {'Title': 'Elon Musk’s SpaceX Starship rocket explodes after launch \xa0– BBC News',
#   'Published_date': '2023-04-20T13:59:13Z',
#   'Views': '2593215',
#   'Comments': '6998',
#   'Dislikes': None,
#   'Likes': '17212'},
#  {'Title': 'US police forces using controversial facial recognition technology - BBC News',
#   'Published_date': '2023-04-20T12:00:36Z',
#   'Views': '147308',
#   'Comments': '612',
#   'Dislikes': None,
#   'Likes': '1909'},
#  {'Title': 'Rare solar eclipse thrills crowds in remote Australia. #Shorts #SolarEclipse #BBCNews',
#   'Published_date': '2023-04-20T11:12:16Z',
#   'Views': '37622',
#   'Comments': '55',
#   'Dislikes': None,
#   'Likes': '1468'},
#  {'Title': 'Rare solar eclipse seen in Western Australia - BBC News',
#   'Published_date': '2023-04-20T10:07:27Z',
#   'Views': '45123',
#   'Comments': '97',
#   'Dislikes': None,
#   'Likes': '671'},
#  {'Title': 'Russian ships accused of North Sea sabotage – BBC News',
#   'Published_date': '2023-04-20T09:00:02Z',
#   'Views': '187920',
#   'Comments': '1528',
#   'Dislikes': None,
#   'Likes': '2056'},
#  {'Title': "Ramadan crush in Yemen's capital Sanaa kills dozens - BBC News",
#   'Published_date': '2023-04-20T07:00:05Z',
#   'Views': '22751',
#   'Comments': '217',
#   'Dislikes': None,
#   'Likes': '295'},
#  {'Title': 'Fox News to pay $787m after claiming votes rigged against Donald Trump - BBC News',
#   'Published_date': '2023-04-19T22:27:35Z',
#   'Views': '218792',
#   'Comments': '1285',
#   'Dislikes': None,
#   'Likes': '1201'},
#  {'Title': 'Alleged Russian spy ships accused of North Sea sabotage - BBC News',
#   'Published_date': '2023-04-19T21:30:06Z',
#   'Views': '404309',
#   'Comments': '2126',
#   'Dislikes': None,
#   'Likes': '4879'},
#  {'Title': 'Mystery spiral seen over Alaskan skies linked to Elon Musk rocket. #Shorts #Space #BBCNews',
#   'Published_date': '2023-04-19T20:30:01Z',
#   'Views': '35029',
#   'Comments': '48',
#   'Dislikes': None,
#   'Likes': '860'},
#  {'Title': "Did Elon Musk's SpaceX cause a mysterious spiral in Alaska? - BBC News",
#   'Published_date': '2023-04-19T19:30:01Z',
#   'Views': '53178',
#   'Comments': '183',
#   'Dislikes': None,
#   'Likes': '781'},
#  {'Title': 'Does Britain’s semiconductor industry risk being left behind? - BBC Newsnight',
#   'Published_date': '2023-04-19T18:30:15Z',
#   'Views': '30390',
#   'Comments': '152',
#   'Dislikes': None,
#   'Likes': '297'},
#  {'Title': 'Why has Apple launched its first store in India? - BBC News',
#   'Published_date': '2023-04-19T17:00:21Z',
#   'Views': '89346',
#   'Comments': '808',
#   'Dislikes': None,
#   'Likes': '1627'},
#  {'Title': 'Alabama shooting: Two teenagers charged with murder over deadly gun attack - BBC News',
#   'Published_date': '2023-04-19T15:30:38Z',
#   'Views': '36770',
#   'Comments': '332',
#   'Dislikes': None,
#   'Likes': '484'},
#  {'Title': 'Warsaw Ghetto Uprising commemorated on 80th anniversary - BBC News',
#   'Published_date': '2023-04-19T14:36:36Z',
#   'Views': '23619',
#   'Comments': '150',
#   'Dislikes': None,
#   'Likes': '601'},
#  {'Title': 'Beijing hospital fire: 12 people detained after blaze kills patients - BBC News',
#   'Published_date': '2023-04-19T13:30:16Z',
#   'Views': '20961',
#   'Comments': '68',
#   'Dislikes': None,
#   'Likes': '276'},
#  {'Title': "TVORCHI - Heart Of Steel: Ukraine's 2023 Eurovision entry - BBC News",
#   'Published_date': '2023-04-19T12:25:00Z',
#   'Views': '10435',
#   'Comments': '105',
#   'Dislikes': None,
#   'Likes': '166'},
#  {'Title': 'Sudan: Gunfire and warplanes crush hopes for ceasefire - BBC News',
#   'Published_date': '2023-04-19T10:55:00Z',
#   'Views': '107894',
#   'Comments': '262',
#   'Dislikes': None,
#   'Likes': '1217'},
#  {'Title': 'Fox News settles Dominion defamation case for $787.5m – BBC News',
#   'Published_date': '2023-04-18T21:45:07Z',
#   'Views': '85451',
#   'Comments': '704',
#   'Dislikes': None,
#   'Likes': '1075'},
#  {'Title': 'Fox News vs Dominion: $1.6bn defamation trial begins in Delaware court - BBC News',
#   'Published_date': '2023-04-18T16:00:24Z',
#   'Views': '48462',
#   'Comments': '454',
#   'Dislikes': None,
#   'Likes': '575'},
#  {'Title': 'Black bear surprises man on sun lounger in North Carolina garden - BBC News',
#   'Published_date': '2023-04-18T14:59:21Z',
#   'Views': '57574',
#   'Comments': '143',
#   'Dislikes': None,
#   'Likes': '730'},
#  {'Title': 'US journalist to stay in Russian prison after appeal rejected - BBC News',
#   'Published_date': '2023-04-18T14:01:04Z',
#   'Views': '29574',
#   'Comments': '269',
#   'Dislikes': None,
#   'Likes': '510'},
#  {'Title': 'Sudan crisis: Will there be a ceasefire? - BBC News',
#   'Published_date': '2023-04-18T13:00:46Z',
#   'Views': '85323',
#   'Comments': '209',
#   'Dislikes': None,
#   'Likes': '734'},
#  {'Title': "FBI makes arrests over US Chinese 'police stations' – BBC News",
#   'Published_date': '2023-04-18T12:00:11Z',
#   'Views': '83325',
#   'Comments': '438',
#   'Dislikes': None,
#   'Likes': '1249'},
#  {'Title': 'Ukraine: Vladimir Putin visits occupied region to meet Russian military, Kremlin says - BBC News',
#   'Published_date': '2023-04-18T11:01:43Z',
#   'Views': '179320',
#   'Comments': '1398',
#   'Dislikes': None,
#   'Likes': '1822'},
#  {'Title': 'Sudan: US talks to rival generals as fighting continues - BBC News',
#   'Published_date': '2023-04-18T09:16:32Z',
#   'Views': '116634',
#   'Comments': '356',
#   'Dislikes': None,
#   'Likes': '1108'},
#  {'Title': "Alabama shooting: Teen died saving sister's life – BBC News",
#   'Published_date': '2023-04-18T07:30:07Z',
#   'Views': '25038',
#   'Comments': '236',
#   'Dislikes': None,
#   'Likes': '376'},
#  {'Title': 'Alabama shooting: Girl survives being shot three times at 16th birthday party - BBC News',
#   'Published_date': '2023-04-17T17:15:00Z',
#   'Views': '183641',
#   'Comments': '832',
#   'Dislikes': None,
#   'Likes': '1305'},
#  {'Title': 'Ukraine war critic Vladimir Kara-Murza jailed for 25 years in Russia – BBC News',
#   'Published_date': '2023-04-17T15:29:03Z',
#   'Views': '46972',
#   'Comments': '752',
#   'Dislikes': None,
#   'Likes': '667'},
#  {'Title': 'SpaceX postpones Starship rocket launch, as Elon Musk blames frozen valve - BBC News',
#   'Published_date': '2023-04-17T13:37:00Z',
#   'Views': '119569',
#   'Comments': '449',
#   'Dislikes': None,
#   'Likes': '1459'},
#  {'Title': 'Myanmar: Life under military rule - BBC News',
#   'Published_date': '2023-04-17T11:55:00Z',
#   'Views': '130668',
#   'Comments': '515',
#   'Dislikes': None,
#   'Likes': '2458'},
#  {'Title': 'Starship: Elon Musk’s SpaceX set to launch world’s most powerful rocket - BBC News',
#   'Published_date': '2023-04-17T11:01:50Z',
#   'Views': '82364',
#   'Comments': '236',
#   'Dislikes': None,
#   'Likes': '1223'},
#  {'Title': 'Sudan: Violence spreads as explosions rock capital - BBC News',
#   'Published_date': '2023-04-17T09:43:15Z',
#   'Views': '154421',
#   'Comments': '438',
#   'Dislikes': None,
#   'Likes': '1556'},
#  {'Title': 'Four dead at Alabama birthday party shooting - BBC News',
#   'Published_date': '2023-04-17T06:42:50Z',
#   'Views': '199024',
#   'Comments': '1782',
#   'Dislikes': None,
#   'Likes': '1378'},
#  {'Title': 'Moments before former Indian MP Atiq Ahmed shot dead live on TV – BBC News',
#   'Published_date': '2023-04-16T16:10:13Z',
#   'Views': '357448',
#   'Comments': '2157',
#   'Dislikes': None,
#   'Likes': '2084'},
#  {'Title': 'Sudan power struggle leaves dozens of civilians dead - BBC News',
#   'Published_date': '2023-04-16T12:30:08Z',
#   'Views': '573636',
#   'Comments': '991',
#   'Dislikes': None,
#   'Likes': '3089'},
#  {'Title': 'The factory making bionic arms for Ukrainian soldiers – BBC News',
#   'Published_date': '2023-04-16T09:16:36Z',
#   'Views': '58791',
#   'Comments': '382',
#   'Dislikes': None,
#   'Likes': '1472'},
#  {'Title': 'Sudan mounts air strikes as Khartoum clashes escalate – BBC News',
#   'Published_date': '2023-04-15T15:57:58Z',
#   'Views': '1007071',
#   'Comments': '1819',
#   'Dislikes': None,
#   'Likes': '7319'},
#  {'Title': 'Is lab-grown chicken the future of food? - BBC News',
#   'Published_date': '2023-04-15T13:00:24Z',
#   'Views': '38683',
#   'Comments': '439',
#   'Dislikes': None,
#   'Likes': '600'},
#  {'Title': 'Japan PM evacuated after apparent smoke bomb blast during speech – BBC News',
#   'Published_date': '2023-04-15T11:05:12Z',
#   'Views': '183216',
#   'Comments': '769',
#   'Dislikes': None,
#   'Likes': '2593'},
#  {'Title': 'The couple who found love while dumpster diving - BBC News',
#   'Published_date': '2023-04-15T08:30:05Z',
#   'Views': '30891',
#   'Comments': '120',
#   'Dislikes': None,
#   'Likes': '643'},
#  {'Title': "Reform of child gender services 'under threat' says former Health Secretary - BBC Newsnight",
#   'Published_date': '2023-04-14T21:30:02Z',
#   'Views': '26747',
#   'Comments': '459',
#   'Dislikes': None,
#   'Likes': '264'},
#  {'Title': 'Jack Teixeira appears in US court charged over Pentagon leaks - BBC News',
#   'Published_date': '2023-04-14T17:45:00Z',
#   'Views': '197095',
#   'Comments': '1058',
#   'Dislikes': None,
#   'Likes': '784'},
#  {'Title': 'French pension age rise to 64 cleared by court - BBC News',
#   'Published_date': '2023-04-14T16:39:30Z',
#   'Views': '77708',
#   'Comments': '781',
#   'Dislikes': None,
#   'Likes': '934'},
#  {'Title': 'Jack Teixeira: How damaging is the US Pentagon documents leak? - BBC News',
#   'Published_date': '2023-04-14T16:00:59Z',
#   'Views': '161804',
#   'Comments': '488',
#   'Dislikes': None,
#   'Likes': '695'},
#  {'Title': "Juice mission blasts off to explore chance of life on Jupiter's icy moons - BBC News",
#   'Published_date': '2023-04-14T15:30:03Z',
#   'Views': '30209',
#   'Comments': '105',
#   'Dislikes': None,
#   'Likes': '516'},
#  {'Title': 'Brazil’s President Lula meets Chinese leader Xi Jinping in Beijing - BBC News',
#   'Published_date': '2023-04-14T14:00:30Z',
#   'Views': '114258',
#   'Comments': '1346',
#   'Dislikes': None,
#   'Likes': '1677'},
#  {'Title': 'How Ukraine and Russia are rewriting the rules of cyber war - BBC News',
#   'Published_date': '2023-04-14T11:30:31Z',
#   'Views': '165127',
#   'Comments': '556',
#   'Dislikes': None,
#   'Likes': '2736'},
#  {'Title': 'Powerful storm Cyclone Ilsa hits Western Australia - BBC News',
#   'Published_date': '2023-04-14T09:30:15Z',
#   'Views': '42146',
#   'Comments': '190',
#   'Dislikes': None,
#   'Likes': '788'},
#  {'Title': "North Korea says it tested 'most powerful' missile to date – BBC News",
#   'Published_date': '2023-04-14T07:45:04Z',
#   'Views': '137914',
#   'Comments': '786',
#   'Dislikes': None,
#   'Likes': '1666'},
#  {'Title': 'Hundreds more pension reform protests take place in France - BBC News',
#   'Published_date': '2023-04-13T20:00:14Z',
#   'Views': '79132',
#   'Comments': '555',
#   'Dislikes': None,
#   'Likes': '860'},
#  {'Title': 'Pentagon leak: Member of Massachusetts Air National Guard arrested - BBC News',
#   'Published_date': '2023-04-13T19:28:59Z',
#   'Views': '415216',
#   'Comments': '2710',
#   'Dislikes': None,
#   'Likes': '4695'},
#  {'Title': 'Arnold Schwarzenegger terminates giant pothole. #Shorts #California #BBCNews',
#   'Published_date': '2023-04-13T18:00:10Z',
#   'Views': '38346',
#   'Comments': '93',
#   'Dislikes': None,
#   'Likes': '1138'},
#  {'Title': 'Probing the global scam network that’s robbed $1.2bn from investors - BBC Newsnight',
#   'Published_date': '2023-04-13T17:00:29Z',
#   'Views': '138437',
#   'Comments': '175',
#   'Dislikes': None,
#   'Likes': '1610'},
#  {'Title': 'US President Biden meets Irish President Higgins in Dublin - BBC News',
#   'Published_date': '2023-04-13T16:05:53Z',
#   'Views': '52382',
#   'Comments': '355',
#   'Dislikes': None,
#   'Likes': '571'},
#  {'Title': 'What was Joe Biden trying to achieve by visiting Northern Ireland? - BBC Newsnight',
#   'Published_date': '2023-04-13T13:59:29Z',
#   'Views': '63551',
#   'Comments': '530',
#   'Dislikes': None,
#   'Likes': '430'},
#  {'Title': 'Prince Harry to attend King Charles coronation without Meghan - BBC News',
#   'Published_date': '2023-04-13T12:30:15Z',
#   'Views': '66368',
#   'Comments': '774',
#   'Dislikes': None,
#   'Likes': '890'},
#  {'Title': "North Korea missile launch sparks 'evacuation' sirens in Japan - BBC News",
#   'Published_date': '2023-04-13T10:57:12Z',
#   'Views': '225966',
#   'Comments': '1112',
#   'Dislikes': None,
#   'Likes': '2095'},
#  {'Title': 'Ukraine flying 40-year-old British helicopter \xa0– BBC News',
#   'Published_date': '2023-04-13T09:30:10Z',
#   'Views': '228815',
#   'Comments': '765',
#   'Dislikes': None,
#   'Likes': '3202'},
#  {'Title': '$7bn FTX cryptocurrency assets recovered, lawyers say - BBC News',
#   'Published_date': '2023-04-13T08:12:41Z',
#   'Views': '32456',
#   'Comments': '257',
#   'Dislikes': None,
#   'Likes': '397'},
#  {'Title': 'Elon Musk says he was forced to buy Twitter for legal reasons- BBC News',
#   'Published_date': '2023-04-12T22:19:15Z',
#   'Views': '264502',
#   'Comments': '2425',
#   'Dislikes': None,
#   'Likes': '2487'},
#  {'Title': "Ukraine's President Zelensky condemns beheading video - BBC News",
#   'Published_date': '2023-04-12T22:15:09Z',
#   'Views': '184327',
#   'Comments': '2313',
#   'Dislikes': None,
#   'Likes': '2806'},
#  {'Title': 'Pentagon documents leak: Who is responsible? - BBC News',
#   'Published_date': '2023-04-12T20:50:09Z',
#   'Views': '99101',
#   'Comments': '460',
#   'Dislikes': None,
#   'Likes': '1046'},
#  {'Title': 'Scientists create robotic hand able to hold objects - BBC News',
#   'Published_date': '2023-04-12T18:00:19Z',
#   'Views': '97843',
#   'Comments': '200',
#   'Dislikes': None,
#   'Likes': '955'},
#  {'Title': "‘Alcoholic' dog makes full recovery. #Shorts #Dogs #BBCNews",
#   'Published_date': '2023-04-12T16:44:38Z',
#   'Views': '41461',
#   'Comments': '43',
#   'Dislikes': None,
#   'Likes': '914'},
#  {'Title': 'Northern Ireland ‘peace babies’ reflect on Good Friday agreement’s 25th anniversary - BBC Newsnight',
#   'Published_date': '2023-04-12T14:30:10Z',
#   'Views': '31377',
#   'Comments': '149',
#   'Dislikes': None,
#   'Likes': '331'},
#  {'Title': 'Joe Biden gives speech in Northern Ireland to mark 25 years of Good Friday Agreement - BBC News',
#   'Published_date': '2023-04-12T12:23:15Z',
#   'Views': '81873',
# ...
#   'Views': '38982',
#   'Comments': '808',
#   'Dislikes': None,
#   'Likes': '597'},
#  {'Title': 'Armenians in Nagorno-Karabakh say they are cut off due to Azerbaijan blockade - BBC News',
#   'Published_date': '2023-01-10T15:30:10Z',
#   'Views': '54862',
#   'Comments': '1549',
#   'Dislikes': None,
#   'Likes': '891'},
#  {'Title': "California's Montecito residents told to flee deadly storm - BBC News",
#   'Published_date': '2023-01-10T14:00:23Z',
#   'Views': '90487',
#   'Comments': '421',
#   'Dislikes': None,
#   'Likes': '964'},
#  {'Title': "Prince Harry's book released after days of leaks - BBC News",
#   'Published_date': '2023-01-10T12:30:05Z',
#   'Views': '58101',
#   'Comments': '579',
#   'Dislikes': None,
#   'Likes': '853'},
#  {'Title': 'Ozone layer may be restored in decades, UN report says - BBC News',
#   'Published_date': '2023-01-10T11:00:00Z',
#   'Views': '59205',
#   'Comments': '475',
#   'Dislikes': None,
#   'Likes': '1490'},
#  {'Title': 'Brazil pro-democracy rallies held to condemn rioters - BBC News',
#   'Published_date': '2023-01-10T09:30:20Z',
#   'Views': '128611',
#   'Comments': '1213',
#   'Dislikes': None,
#   'Likes': '2711'},
#  {'Title': 'UK space launch: Anomaly prevents rocket reaching orbit - BBC News',
#   'Published_date': '2023-01-10T00:23:30Z',
#   'Views': '153641',
#   'Comments': '336',
#   'Dislikes': None,
#   'Likes': '1110'},
#  {'Title': '1,500 detained in Brazil after right-wing protesters storm Congress - BBC News',
#   'Published_date': '2023-01-09T22:52:37Z',
#   'Views': '84267',
#   'Comments': '946',
#   'Dislikes': None,
#   'Likes': '1437'},
#  {'Title': 'What do the Bolsonaro protesters in Brazil want? - BBC News',
#   'Published_date': '2023-01-09T20:30:02Z',
#   'Views': '68835',
#   'Comments': '696',
#   'Dislikes': None,
#   'Likes': '834'},
#  {'Title': 'India aims to become global drone hub by 2030 - BBC News',
#   'Published_date': '2023-01-09T18:00:01Z',
#   'Views': '142451',
#   'Comments': '1356',
#   'Dislikes': None,
#   'Likes': '3211'},
#  {'Title': 'UN calls for billions of dollars in aid for Pakistan following devastating floods - BBC News',
#   'Published_date': '2023-01-09T17:00:34Z',
#   'Views': '29323',
#   'Comments': '428',
#   'Dislikes': None,
#   'Likes': '390'},
#  {'Title': 'Old Nazi map sparks treasure hunt in Netherlands - BBC News',
#   'Published_date': '2023-01-09T15:00:01Z',
#   'Views': '71379',
#   'Comments': '202',
#   'Dislikes': None,
#   'Likes': '941'},
#  {'Title': "'Once in a century' flooding hits Australia - BBC News",
#   'Published_date': '2023-01-09T13:30:08Z',
#   'Views': '98587',
#   'Comments': '568',
#   'Dislikes': None,
#   'Likes': '1160'},
#  {'Title': 'Ukraine denies Russian claim it killed more than 600 of its soldiers - BBC News',
#   'Published_date': '2023-01-09T12:00:26Z',
#   'Views': '100666',
#   'Comments': '894',
#   'Dislikes': None,
#   'Likes': '1687'},
#  {'Title': 'China opens borders to international visitors for first time since 2020 - BBC News',
#   'Published_date': '2023-01-09T10:30:03Z',
#   'Views': '48078',
#   'Comments': '318',
#   'Dislikes': None,
#   'Likes': '670'},
#  {'Title': 'Brazilian forces regain control after Congress stormed - BBC News',
#   'Published_date': '2023-01-09T08:58:32Z',
#   'Views': '218768',
#   'Comments': '2058',
#   'Dislikes': None,
#   'Likes': '4034'},
#  {'Title': 'Russian attacks on Ukraine continue despite ceasefire promises - BBC News',
#   'Published_date': '2023-01-08T15:15:02Z',
#   'Views': '187942',
#   'Comments': '1666',
#   'Dislikes': None,
#   'Likes': '2517'},
#  {'Title': 'US condemns Iran for hanging anti-government protesters - BBC News',
#   'Published_date': '2023-01-08T14:15:02Z',
#   'Views': '70514',
#   'Comments': '781',
#   'Dislikes': None,
#   'Likes': '778'},
#  {'Title': 'China reopens borders to international visitors after three years of Covid closure - BBC News',
#   'Published_date': '2023-01-08T13:02:44Z',
#   'Views': '97172',
#   'Comments': '520',
#   'Dislikes': None,
#   'Likes': '770'},
#  {'Title': 'Looted ancient sarcophagus returned to Egypt – BBC News',
#   'Published_date': '2023-01-08T12:00:02Z',
#   'Views': '68527',
#   'Comments': '374',
#   'Dislikes': None,
#   'Likes': '1301'},
#  {'Title': 'How does Transformers’ robot Optimus Prime work? – BBC News',
#   'Published_date': '2023-01-08T08:00:23Z',
#   'Views': '57983',
#   'Comments': '245',
#   'Dislikes': None,
#   'Likes': '1315'},
#  {'Title': 'RuPaul’s DragCon UK 2023 takes place in London – BBC News',
#   'Published_date': '2023-01-07T17:28:57Z',
#   'Views': '68787',
#   'Comments': '1543',
#   'Dislikes': None,
#   'Likes': '1111'},
#  {'Title': "At least 29 killed during arrest of El Chapo's son in Mexico - BBC News",
#   'Published_date': '2023-01-07T13:30:10Z',
#   'Views': '1970795',
#   'Comments': '3437',
#   'Dislikes': None,
#   'Likes': '16132'},
#  {'Title': 'Ukraine President Zelensky thanks Western allies for sending fighting vehicles to Kyiv - BBC News',
#   'Published_date': '2023-01-07T12:15:04Z',
#   'Views': '363560',
#   'Comments': '2133',
#   'Dislikes': None,
#   'Likes': '5763'},
#  {'Title': 'Boy, six, detained after shooting teacher in US - BBC News',
#   'Published_date': '2023-01-07T11:30:13Z',
#   'Views': '89319',
#   'Comments': '1037',
#   'Dislikes': None,
#   'Likes': '1037'},
#  {'Title': 'Kevin McCarthy elected US House Speaker after 15 rounds of voting - BBC News',
#   'Published_date': '2023-01-07T11:05:20Z',
#   'Views': '90626',
#   'Comments': '434',
#   'Dislikes': None,
#   'Likes': '731'},
#  {'Title': 'Inside the factory making a flying car ready for take off - BBC News',
#   'Published_date': '2023-01-07T09:28:13Z',
#   'Views': '194443',
#   'Comments': '462',
#   'Dislikes': None,
#   'Likes': '2663'},
#  {'Title': 'Dramatic moments from a week of chaos in Congress - BBC News',
#   'Published_date': '2023-01-07T06:19:22Z',
#   'Views': '58969',
#   'Comments': '231',
#   'Dislikes': None,
#   'Likes': '953'},
#  {'Title': 'Sir Keir Starmer: What do we know about the man who wants to be the UK’s next PM? - BBC Newsnight',
#   'Published_date': '2023-01-06T19:00:10Z',
#   'Views': '68269',
#   'Comments': '728',
#   'Dislikes': None,
#   'Likes': '1059'},
#  {'Title': 'LGBTQ activist Edwin Chiloba found dead in Kenya – BBC News',
#   'Published_date': '2023-01-06T15:53:36Z',
#   'Views': '89194',
#   'Comments': '1527',
#   'Dislikes': None,
#   'Likes': '1198'},
#  {'Title': "Sierra Madre: Fighting to save what's left of a vital rainforest in the Philippines – BBC News",
#   'Published_date': '2023-01-06T14:00:11Z',
#   'Views': '35222',
#   'Comments': '115',
#   'Dislikes': None,
#   'Likes': '738'},
#  {'Title': "Prince Harry makes series of claims and accusations in memoir 'Spare' – BBC News",
#   'Published_date': '2023-01-06T12:52:36Z',
#   'Views': '114746',
#   'Comments': '1265',
#   'Dislikes': None,
#   'Likes': '979'},
#  {'Title': 'Do rail strikes risk putting Brits off trains for good? - BBC Newsnight',
#   'Published_date': '2023-01-06T12:13:32Z',
#   'Views': '55878',
#   'Comments': '476',
#   'Dislikes': None,
#   'Likes': '755'},
#  {'Title': "El Chapo's son’s arrest sparks deadly riots in Mexican state – BBC News",
#   'Published_date': '2023-01-06T10:03:35Z',
#   'Views': '735022',
#   'Comments': '1828',
#   'Dislikes': None,
#   'Likes': '6611'},
#  {'Title': "Ukraine rejects President Putin's Russian Orthodox Christmas truce – BBC News",
#   'Published_date': '2023-01-06T08:38:41Z',
#   'Views': '408672',
#   'Comments': '3423',
#   'Dislikes': None,
#   'Likes': '5695'},
#  {'Title': 'CES: Gadgets unveiled at one of world’s largest technology shows – BBC News',
#   'Published_date': '2023-01-05T19:34:06Z',
#   'Views': '50316',
#   'Comments': '85',
#   'Dislikes': None,
#   'Likes': '530'},
#  {'Title': 'How Ukraine’s deadly new year attack on Russian troops in Makiivka unfolded – BBC News',
#   'Published_date': '2023-01-05T16:58:22Z',
#   'Views': '382786',
#   'Comments': '1281',
#   'Dislikes': None,
#   'Likes': '4379'},
#  {'Title': 'Sri Lanka parents forced to pick which child can go to school – BBC News',
#   'Published_date': '2023-01-05T16:40:50Z',
#   'Views': '131606',
#   'Comments': '512',
#   'Dislikes': None,
#   'Likes': '1996'},
#  {'Title': "What's happening with the US House of Representatives speaker election? – BBC News",
#   'Published_date': '2023-01-05T15:34:32Z',
#   'Views': '143129',
#   'Comments': '510',
#   'Dislikes': None,
#   'Likes': '1319'},
#  {'Title': 'Amazon to axe 18,000 jobs globally as it cuts costs – BBC News',
#   'Published_date': '2023-01-05T10:52:55Z',
#   'Views': '66882',
#   'Comments': '294',
#   'Dislikes': None,
#   'Likes': '1067'},
#  {'Title': 'Ukraine frontline:  the battle for Bakhmut - BBC News',
#   'Published_date': '2023-01-04T22:56:10Z',
#   'Views': '1987620',
#   'Comments': '5829',
#   'Dislikes': None,
#   'Likes': '22817'},
#  {'Title': "Warm winter temperatures across Europe 'extreme weather event', say meteorologists - BBC News",
#   'Published_date': '2023-01-04T17:30:07Z',
#   'Views': '97056',
#   'Comments': '663',
#   'Dislikes': None,
#   'Likes': '1141'},
#  {'Title': 'NFL star Damar Hamlin remains in critical condition after cardiac arrest - BBC News',
#   'Published_date': '2023-01-04T15:30:03Z',
#   'Views': '24726',
#   'Comments': '276',
#   'Dislikes': None,
#   'Likes': '262'},
#  {'Title': 'Travel restrictions on Chinese arrivals are politically motivated, says China - BBC News',
#   'Published_date': '2023-01-04T13:30:17Z',
#   'Views': '88639',
#   'Comments': '822',
#   'Dislikes': None,
#   'Likes': '997'},
#  {'Title': "Russia blames Ukraine missile attack on soldiers' mobile phone use - BBC News",
#   'Published_date': '2023-01-04T11:30:29Z',
#   'Views': '140463',
#   'Comments': '983',
#   'Dislikes': None,
#   'Likes': '1760'},
#  {'Title': 'House of Representatives fails to elect Speaker for first time in 100 years - BBC News',
#   'Published_date': '2023-01-04T09:30:00Z',
#   'Views': '134655',
#   'Comments': '987',
#   'Dislikes': None,
#   'Likes': '2185'},
#  {'Title': 'What does it take to raise a guide dog puppy? - BBC News',
#   'Published_date': '2023-01-03T21:00:21Z',
#   'Views': '39156',
#   'Comments': '82',
#   'Dislikes': None,
#   'Likes': '678'},
#  {'Title': 'China criticises Covid travel restrictions and warns of retaliation - BBC News',
#   'Published_date': '2023-01-03T19:15:46Z',
#   'Views': '210412',
#   'Comments': '1782',
#   'Dislikes': None,
#   'Likes': '1437'},
#  {'Title': 'Crowds line streets to pay final respects to Brazil football legend Pele - BBC News',
#   'Published_date': '2023-01-03T16:34:22Z',
#   'Views': '105665',
#   'Comments': '108',
#   'Dislikes': None,
#   'Likes': '1129'},
#  {'Title': 'British couple killed in Australia helicopter crash named - BBC News',
#   'Published_date': '2023-01-03T15:17:46Z',
#   'Views': '57933',
#   'Comments': '132',
#   'Dislikes': None,
#   'Likes': '373'},
#  {'Title': 'Mourners queue through night to pay respects to Brazil legend Pele ahead of funeral -  BBC News',
#   'Published_date': '2023-01-03T11:48:36Z',
#   'Views': '66212',
#   'Comments': '168',
#   'Dislikes': None,
#   'Likes': '1325'},
#  {'Title': "Russia plans to 'exhaust' Ukraine with prolonged attacks says Volodymyr Zelensky -  BBC News",
#   'Published_date': '2023-01-03T10:06:24Z',
#   'Views': '214421',
#   'Comments': '1732',
#   'Dislikes': None,
#   'Likes': '2679'},
#  {'Title': 'NFL star Damar Hamlin suffers cardiac arrest during primetime game - BBC News',
#   'Published_date': '2023-01-03T08:40:33Z',
#   'Views': '75986',
#   'Comments': '366',
#   'Dislikes': None,
#   'Likes': '472'},
#  {'Title': '“Up to 400 Russian soldiers killed” in Ukraine missile strike - BBC News',
#   'Published_date': '2023-01-02T23:11:12Z',
#   'Views': '841692',
#   'Comments': '4586',
#   'Dislikes': None,
#   'Likes': '9583'},
#  {'Title': 'Ukraine claims hundreds of Russian soldiers killed by missile attack - BBC News',
#   'Published_date': '2023-01-02T16:36:38Z',
#   'Views': '491411',
#   'Comments': '2927',
#   'Dislikes': None,
#   'Likes': '6079'},
#  {'Title': 'Lula sworn in as Brazil president - BBC News',
#   'Published_date': '2023-01-02T12:15:03Z',
#   'Views': '58444',
#   'Comments': '533',
#   'Dislikes': None,
#   'Likes': '1405'},
#  {'Title': 'Former Pope Benedict XVI lying in state at Vatican begins - BBC News',
#   'Published_date': '2023-01-02T10:14:19Z',
#   'Views': '51974',
#   'Comments': '289',
#   'Dislikes': None,
#   'Likes': '728'},
#  {'Title': 'Lula to be sworn in as Brazil president as Bolsonaro flies to US - BBC News',
#   'Published_date': '2023-01-01T19:30:01Z',
#   'Views': '70337',
#   'Comments': '602',
#   'Dislikes': None,
#   'Likes': '1107'},
#  {'Title': 'Pope Francis and world leaders pay tribute to Benedict XVI - BBC News',
#   'Published_date': '2023-01-01T18:30:47Z',
#   'Views': '39271',
#   'Comments': '236',
#   'Dislikes': None,
#   'Likes': '367'},
#  {'Title': 'Countries around the world celebrate the New Year after Covid lull - BBC News',
#   'Published_date': '2023-01-01T17:30:04Z',
#   'Views': '118980',
#   'Comments': '215',
#   'Dislikes': None,
#   'Likes': '1584'},
#  {'Title': 'Croatia joins eurozone and Schengen area - BBC News',
#   'Published_date': '2023-01-01T16:41:51Z',
#   'Views': '151013',
#   'Comments': '1261',
#   'Dislikes': None,
#   'Likes': '2096'},
#  {'Title': 'Ukraine’s Zelensky and Russia’s Putin address their countries on New Year’s Eve  – BBC News',
#   'Published_date': '2023-01-01T11:42:14Z',
#   'Views': '552730',
#   'Comments': '4622',
#   'Dislikes': None,
#   'Likes': '6974'},
#  {'Title': "2022's biggest stories... in 74 seconds – BBC News",
#   'Published_date': '2023-01-01T10:00:11Z',
#   'Views': '356017',
#   'Comments': '575',
#   'Dislikes': None,
#   'Likes': '8969'},
#  {'Title': "Music 'essential to mental health' as people listen more than ever before  - BBC News",
#   'Published_date': '2023-01-01T08:56:56Z',
#   'Views': '44649',
#   'Comments': '294',
#   'Dislikes': None,
#   'Likes': '1136'},
#  {'Title': 'More countries to Covid test passengers arriving from China - BBC News',
#   'Published_date': '2022-12-31T18:00:00Z',
#   'Views': '164249',
#   'Comments': '983',
#   'Dislikes': None,
#   'Likes': '1822'},
#  {'Title': 'US news anchor Barbara Walters dies aged 93 – BBC News',
#   'Published_date': '2022-12-31T12:30:05Z',
#   'Views': '37224',
#   'Comments': '175',
#   'Dislikes': None,
#   'Likes': '483'},
#  {'Title': 'Former Pope Benedict XVI dies aged 95 - BBC News',
#   'Published_date': '2022-12-31T10:23:11Z',
#   'Views': '114962',
#   'Comments': '1341',
#   'Dislikes': None,
#   'Likes': '2818'},
#  {'Title': 'Has the war in Ukraine changed Russia? - BBC News',
#   'Published_date': '2022-12-30T20:23:55Z',
#   'Views': '1375459',
#   'Comments': '9785',
#   'Dislikes': None,
#   'Likes': '17379'},
#  {'Title': "Donald Trump's tax returns released after years-long effort – BBC News",
#   'Published_date': '2022-12-30T16:30:03Z',
#   'Views': '127879',
#   'Comments': '1426',
#   'Dislikes': None,
#   'Likes': '1401'},
#  {'Title': 'Andrew Tate detained in Romania over rape and human trafficking case - BBC News',
#   'Published_date': '2022-12-30T14:35:15Z',
#   'Views': '319921',
#   'Comments': '4491',
#   'Dislikes': None,
#   'Likes': '4466'},
#  {'Title': 'Myanmar’s former leader Aung San Suu Kyi jailed for a further seven years – BBC News',
#   'Published_date': '2022-12-30T10:15:00Z',
#   'Views': '84560',
#   'Comments': '565',
#   'Dislikes': None,
#   'Likes': '1010'},
#  {'Title': "Pelé - Brazil's football legend, has died - BBC News",
#   'Published_date': '2022-12-29T22:49:10Z',
#   'Views': '642805',
#   'Comments': '1848',
#   'Dislikes': None,
#   'Likes': '11201'},
#  {'Title': 'Israel’s hard-line new government takes office – BBC News',
#   'Published_date': '2022-12-29T17:47:11Z',
#   'Views': '67946',
#   'Comments': '932',
#   'Dislikes': None,
#   'Likes': '982'},
#  {'Title': 'The Texas school where every student is a teen mother – BBC News',
#   'Published_date': '2022-12-29T13:11:13Z',
#   'Views': '108810',
#   'Comments': '1088',
#   'Dislikes': None,
#   'Likes': '2093'},
#  {'Title': '120 Russian missiles target Ukrainian cities in fresh strikes – BBC News',
#   'Published_date': '2022-12-29T10:50:48Z',
#   'Views': '280587',
#   'Comments': '2915',
#   'Dislikes': None,
#   'Likes': '3731'},
#  {'Title': 'US considers Covid restrictions on China arrivals - BBC News',
#   'Published_date': '2022-12-28T17:30:04Z',
#   'Views': '212112',
#   'Comments': '1996',
#   'Dislikes': None,
#   'Likes': '1530'},
#  ...]

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
df = video_data

# %%
df.head(10)
# Out:
#                                                Title        Published_date  \
# 0  Russia’s Victory Day parade: President Putin c...  2023-05-09T11:15:03Z
# 1  Pakistan’s former PM Imran Khan arrested outsi...  2023-05-09T10:30:58Z
# 2  Apple co-founder says AI may make scams harder...  2023-05-09T09:28:26Z
# 3  Ukraine says it downed Russian cruise missiles...  2023-05-09T07:16:28Z
# 4  Brownsville: Eight dead as car strikes people ...  2023-05-08T16:00:12Z
# 5  More than 400 killed in Democratic Republic of...  2023-05-08T14:29:40Z
# 6  St Kitts and Nevis is not totally free under K...  2023-05-08T11:38:36Z
# 7  Ukraine’s Kyiv faces fourth missile attack fro...  2023-05-08T09:09:24Z
# 8  Coronation concert: Prince William 'so proud' ...  2023-05-07T21:59:47Z
# 9  Brownsville: Seven dead in Texas as car strike...  2023-05-07T19:36:24Z
#
#     Views Comments Dislikes Likes
# 0   44716      864     None  1017
# 1   22688      454     None   677
# 2    9565        0     None   332
# 3   34443      330     None   561
# 4   28769      204     None   341
# 5   23399      116     None   546
# 6   66572      668     None   954
# 7  207438     1991     None  2339
# 8  151163      624     None  1700
# 9   92891      990     None   955

# %%
df.sort_values(by=['Views'],ascending=True)
# Out:
#                                                    Title  \
# 6163   Greece toughens policy on illegal immigrants -...
# 17765  In the thick of Rio riots over rail fare - BBC...
# 3088   China and Russia declare “no limits” to their ...
# 3084   Queen backs Camilla to be Queen Consort on Jub...
# 13065    Is there life on Mars? Patrick Moore - BBC News
# ...                                                  ...
# 7185   Coronavirus social distancing advice: What two...
# 13925  Ecuador earthquake: 'There's nothing left. Onl...
# 13231  Syria: Assad 'must be more responsible' says J...
# 7201   Viral dad on the trials of working from home -...
# 17820                   What kind of neighbour is China?
#
#              Published_date    Views Comments Dislikes  Likes
# 6163   2020-08-31T21:35:45Z   100001      794     None   1178
# 17765  2014-02-07T12:23:31Z    10001       18     None     44
# 3088   2022-02-04T22:25:28Z  1000335     6906     None  11129
# 3084   2022-02-06T10:37:31Z   100054     1071     None   1651
# 13065  2016-10-19T16:15:34Z    10007       29     None    117
# ...                     ...      ...      ...      ...    ...
# 7185   2020-03-29T11:46:55Z    99963      337     None   1042
# 13925  2016-04-22T07:48:00Z     9997        5     None     49
# 13231  2016-09-19T10:22:14Z     9997      117     None     52
# 7201   2020-03-26T13:41:37Z   999731      660     None   5787
# 17820  2014-01-27T12:06:18Z     None       57     None     49
#
# [18356 rows x 6 columns]

# %%
df.to_csv('bbc_youtube.csv')
